# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the datasets
data = pd.read_csv('data.csv')  # Crop recommendation dataset
icrisat_df = pd.read_csv('ICRISAT-District Level Data.csv')  # Harvest price dataset

# Display column names for reference
print("ICRISAT Dataset Columns:", icrisat_df.columns)
# Out:
# ICRISAT Dataset Columns: Index(['Dist Code', 'Year', 'State Code', 'State Name', 'Dist Name',
#        'RICE HARVEST PRICE (Rs per Quintal)',
#        'PADDY HARVEST PRICE (Rs per Quintal)',
#        'WHEAT HARVEST PRICE (Rs per Quintal)',
#        'SORGHUM HARVEST PRICE (Rs per Quintal)',
#        'PEARL MILLET HARVEST PRICE (Rs per Quintal)',
#        'MAIZE HARVEST PRICE (Rs per Quintal)',
#        'FINGER MILLET HARVEST PRICE (Rs per Quintal)',
#        'BARLEY HARVEST PRICE (Rs per Quintal)',
#        'CHICKPEA HARVEST PRICE (Rs per Quintal)',
#        'PIGEONPEA HARVEST PRICE (Rs per Quintal)',
#        'GROUNDNUT HARVEST PRICE (Rs per Quintal)',
#        'SEASMUM HARVEST PRICE (Rs per Quintal)',
#        'RAPE AND MUSTARD HARVEST PRICE (Rs per Quintal)',
#        'CASTOR HARVEST PRICE (Rs per Quintal)',
#        'LINSEED HARVEST PRICE (Rs per Quintal)',
#        'SUGARCANE GUR HARVEST PRICE (Rs per Quintal)',
#        'COTTON KAPAS HARVEST PRICE (Rs per Quintal)'],
#       dtype='object')

# %%
def estimate_income(crop_column, area, filtered_data):
    """
    Estimate income for a given crop and area.
    :param crop_column: The column name representing the crop's harvest price.
    :param area: The area allocated to the crop (in hectares).
    :param filtered_data: Filtered ICRISAT data based on user inputs.
    :return: Estimated income (in Rs).
    """
    if crop_column in filtered_data.columns:
        avg_price = filtered_data[crop_column].mean()  # Average price per quintal
        yield_per_hectare = 20  # Assume 20 quintals/ha (adjust based on actual data)
        return avg_price * yield_per_hectare * area
    return 0

# %%
def optimize_crop_combination(available_area, filtered_data, top_n=5):
    """
    Optimize crop combinations to maximize income.
    :param available_area: Total available area (in hectares).
    :param filtered_data: Filtered ICRISAT data based on user inputs.
    :param top_n: Number of top combinations to return.
    :return: List of top N combinations with maximum income.
    """
    # Filter columns that represent harvest prices
    crop_columns = [col for col in filtered_data.columns if 'HARVEST PRICE' in col]
    
    combinations = []
    
    for crop1 in crop_columns:
        for crop2 in crop_columns:
            if crop1 != crop2:
                for area1 in range(1, available_area):  # Allocate area to crop1
                    area2 = available_area - area1  # Remaining area for crop2
                    
                    # Calculate income for both crops
                    income1 = estimate_income(crop1, area1, filtered_data)
                    income2 = estimate_income(crop2, area2, filtered_data)
                    total_income = income1 + income2
                    
                    # Store the combination details
                    combinations.append({
                        'crop1': crop1,
                        'area1': area1,
                        'crop2': crop2,
                        'area2': area2,
                        'total_income': total_income
                    })
    
    # Sort combinations by total income and return the top N results
    return sorted(combinations, key=lambda x: x['total_income'], reverse=True)[:top_n]

# %%
# Collect user inputs
state = input("Enter state: ")
district = input("Enter district: ")
market = input("Enter market: ")
predicted_commodity = input("Enter predicted commodity: ")
land_size = float(input("Enter the size of land in hectares: "))

# Filter ICRISAT data based on user inputs (state and district)
filtered_icrisat_df = icrisat_df[
    (icrisat_df['State Name'] == state) & 
    (icrisat_df['Dist Name'] == district)
]

# Check if data is available for the given inputs
if filtered_icrisat_df.empty:
    print(f"No data found for State: {state}, District: {district}. Please try again.")
else:
    print(f"Filtered data contains {filtered_icrisat_df.shape[0]} rows.")
# Out:
# No data found for State: maharashtra, District: thane. Please try again.

# %%
if not filtered_icrisat_df.empty:
    # Get top 5 crop combinations for maximum income
    top_combinations = optimize_crop_combination(land_size, filtered_icrisat_df)

    # Display results
    print("\nTop 5 Crop Combinations for Maximum Income:")
    for i, combo in enumerate(top_combinations, 1):
        print(f"{i}. {combo['crop1']} ({combo['area1']} ha) + {combo['crop2']} ({combo['area2']} ha)")
        print(f"   Estimated Income: ₹{combo['total_income']:,.2f}")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Load the datasets
data = pd.read_csv('data.csv')  # Crop recommendation dataset
icrisat_df = pd.read_csv('ICRISAT-District Level Data.csv')  # Harvest price dataset

# Display column names for reference
print("ICRISAT Dataset Columns:", icrisat_df.columns)
def estimate_income(crop_column, area):
    """
    Estimate income for a given crop and area.
    :param crop_column: The column name representing the crop's harvest price.
    :param area: The area allocated to the crop (in hectares).
    :return: Estimated income (in Rs).
    """
    if crop_column in icrisat_df.columns:
        avg_price = icrisat_df[crop_column].mean()  # Average price per quintal
        yield_per_hectare = 20  # Assume 20 quintals/ha (adjust based on actual data)
        return avg_price * yield_per_hectare * area
    return 0
def optimize_crop_combination(available_area, top_n=5):
    """
    Optimize crop combinations to maximize income.
    :param available_area: Total available area (in hectares).
    :param top_n: Number of top combinations to return.
    :return: List of top N combinations with maximum income.
    """
    # Filter columns that represent harvest prices
    crop_columns = [col for col in icrisat_df.columns if 'HARVEST PRICE' in col]
    
    combinations = []
    
    for crop1 in crop_columns:
        for crop2 in crop_columns:
            if crop1 != crop2:
                for area1 in range(1, available_area):  # Allocate area to crop1
                    area2 = available_area - area1  # Remaining area for crop2
                    
                    # Calculate income for both crops
                    income1 = estimate_income(crop1, area1)
                    income2 = estimate_income(crop2, area2)
                    total_income = income1 + income2
                    
                    # Store the combination details
                    combinations.append({
                        'crop1': crop1,
                        'area1': area1,
                        'crop2': crop2,
                        'area2': area2,
                        'total_income': total_income
                    })
    
    # Sort combinations by total income and return the top N results
    return sorted(combinations, key=lambda x: x['total_income'], reverse=True)[:top_n]
# Set available land area (in hectares)
available_area = 100

# Get top 5 crop combinations for maximum income
top_combinations = optimize_crop_combination(available_area)

# Display results
# Out:
# ICRISAT Dataset Columns: Index(['Dist Code', 'Year', 'State Code', 'State Name', 'Dist Name',
#        'RICE HARVEST PRICE (Rs per Quintal)',
#        'PADDY HARVEST PRICE (Rs per Quintal)',
#        'WHEAT HARVEST PRICE (Rs per Quintal)',
#        'SORGHUM HARVEST PRICE (Rs per Quintal)',
#        'PEARL MILLET HARVEST PRICE (Rs per Quintal)',
#        'MAIZE HARVEST PRICE (Rs per Quintal)',
#        'FINGER MILLET HARVEST PRICE (Rs per Quintal)',
#        'BARLEY HARVEST PRICE (Rs per Quintal)',
#        'CHICKPEA HARVEST PRICE (Rs per Quintal)',
#        'PIGEONPEA HARVEST PRICE (Rs per Quintal)',
#        'GROUNDNUT HARVEST PRICE (Rs per Quintal)',
#        'SEASMUM HARVEST PRICE (Rs per Quintal)',
#        'RAPE AND MUSTARD HARVEST PRICE (Rs per Quintal)',
#        'CASTOR HARVEST PRICE (Rs per Quintal)',
#        'LINSEED HARVEST PRICE (Rs per Quintal)',
#        'SUGARCANE GUR HARVEST PRICE (Rs per Quintal)',
#        'COTTON KAPAS HARVEST PRICE (Rs per Quintal)'],
#       dtype='object')

# %%
print("\nTop 5 Crop Combinations for Maximum Income:")
for i, combo in enumerate(top_combinations, 1):
    print(f"{i}. {combo['crop1']} ({combo['area1']} ha) + {combo['crop2']} ({combo['area2']} ha)")
    print(f"   Estimated Income: ₹{combo['total_income']:,.2f}")
# Out:
# Top 5 Crop Combinations for Maximum Income:
# 1. CHICKPEA HARVEST PRICE (Rs per Quintal) (1 ha) + SEASMUM HARVEST PRICE (Rs per Quintal) (99 ha)
#    Estimated Income: ₹2,023,172.41
# 2. SEASMUM HARVEST PRICE (Rs per Quintal) (99 ha) + CHICKPEA HARVEST PRICE (Rs per Quintal) (1 ha)
#    Estimated Income: ₹2,023,172.41
# 3. GROUNDNUT HARVEST PRICE (Rs per Quintal) (1 ha) + SEASMUM HARVEST PRICE (Rs per Quintal) (99 ha)
#    Estimated Income: ₹2,021,896.21
# 4. SEASMUM HARVEST PRICE (Rs per Quintal) (99 ha) + GROUNDNUT HARVEST PRICE (Rs per Quintal) (1 ha)
#    Estimated Income: ₹2,021,896.21
# 5. PIGEONPEA HARVEST PRICE (Rs per Quintal) (1 ha) + SEASMUM HARVEST PRICE (Rs per Quintal) (99 ha)
#    Estimated Income: ₹2,021,513.18

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
from scipy.optimize import minimize

# Load datasets
crop_df = pd.read_csv('data.csv')  # Crop recommendation data
yield_df = pd.read_csv('commodity_yield.csv')
icrisat_df = pd.read_csv('ICRISAT-District Level Data.csv')

def preprocess_data():
    """Preprocess and integrate datasets."""
    # Create price mapping from ICRISAT data
    price_columns = [col for col in icrisat_df.columns if 'HARVEST PRICE' in col]
    price_map = {}
    for col in price_columns:
        crop_name = col.split(' HARVEST')[0].strip().lower()
        price_map[crop_name] = icrisat_df[col].mean()
    return price_map

def recommend_crops(farm_conditions):
    """Recommend crops using KNN."""
    X = crop_df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
    y = crop_df['label']
    
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X, y)
    
    probabilities = knn.predict_proba([farm_conditions])[0]
    crops = knn.classes_
    
    # Sort crops by probability in descending order
    return sorted(zip(crops, probabilities), key=lambda x: x[1], reverse=True)

def optimize_allocation(recommended_crops, total_area, price_map):
    """Optimize land allocation for maximum revenue."""
    crop_data = []
    
    for crop, prob in recommended_crops:
        yield_q = yield_df[yield_df['Commodity'].str.lower() == crop.lower()]['Yield_Quintals_Per_Hectare'].values
        price = price_map.get(crop.lower(), 0)
        if len(yield_q) > 0 and price > 0:
            crop_data.append({
                'crop': crop,
                'yield': yield_q[0],
                'price': price,
                'prob': prob
            })
    
    # If no valid crops are found, return empty lists
    if not crop_data:
        print("No valid crops found with sufficient yield and price data.")
        return [], []

    # Objective function to maximize revenue (negative for minimization)
    def objective(areas):
        return -sum(area * crop['yield'] * crop['price'] for area, crop in zip(areas, crop_data))
    
    # Constraints: total area must equal the given area
    constraints = [{'type': 'eq', 'fun': lambda x: np.sum(x) - total_area}]
    
    # Bounds: each crop's area must be between 0 and total_area
    bounds = [(0, total_area) for _ in crop_data]
    
    # Initial guess: equal distribution of area among crops
    x0 = [total_area / len(crop_data)] * len(crop_data)
    
    # Solve optimization problem
    result = minimize(objective, x0, method='SLSQP', bounds=bounds, constraints=constraints)
    
    return result.x, crop_data

def main():
    # Input farm conditions and total land area
    farm_conditions = [
        float(input(f"Enter {param}: ")) for param in 
        ['N (kg/ha)', 'P (kg/ha)', 'K (kg/ha)', 'Temperature (°C)', 
         'Humidity (%)', 'pH', 'Rainfall (mm)']
    ]
    total_area = float(input("Enter total available area (hectares): "))
    
    # Preprocess data and get price mapping
    price_map = preprocess_data()
    
    # Recommend crops based on farm conditions
    recommendations = recommend_crops(farm_conditions)
    
    print("\nTop Recommended Crops:")
    for crop, prob in recommendations[:5]:
        print(f"- {crop.capitalize()} (Probability: {prob:.2%})")
    
    # Optimize land allocation for maximum revenue
    areas, crop_data = optimize_allocation(recommendations[:5], total_area, price_map)
    
    if not areas:
        print("No optimal allocation could be determined due to insufficient data.")
        return
    
    # Display results
    print("\nOptimal Allocation:")
    total_revenue = 0
    for area, data in zip(areas, crop_data):
        if area > 0:
            revenue = area * data['yield'] * data['price']
            total_revenue += revenue
            print(f"{data['crop'].capitalize()}: {area:.1f} ha (₹{revenue:,.0f})")
    
    print(f"\nTotal Estimated Revenue: ₹{total_revenue:,.0f}")

if __name__ == "__main__":
    main()
# Out:
# Top Recommended Crops:
# - Rice (Probability: 100.00%)
# - Apple (Probability: 0.00%)
# - Banana (Probability: 0.00%)
# - Blackgram (Probability: 0.00%)
# - Chickpea (Probability: 0.00%)
#
# Optimal Allocation:
# Rice: 500.0 ha (₹2,800,806)
#
# Total Estimated Revenue: ₹2,800,806
# c:\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import itertools

# Load datasets
crop_df = pd.read_csv('data.csv')
yield_df = pd.read_csv('commodity_yield.csv')
icrisat_df = pd.read_csv('ICRISAT-District Level Data.csv')

def preprocess_data():
    """Extract crop price data from ICRISAT dataset."""
    price_columns = [col for col in icrisat_df.columns if 'HARVEST PRICE' in col]
    crop_prices = {}
    
    for column in price_columns:
        crop_name = column.split(' HARVEST')[0].strip()
        crop_prices[crop_name] = icrisat_df[column].mean()
    
    return crop_prices, price_columns

def recommend_crops(farm_conditions):
    """Recommend crops using KNN based on farm conditions."""
    X = crop_df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
    y = crop_df['label']
    
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X, y)
    
    probabilities = knn.predict_proba([farm_conditions])[0]
    crops = knn.classes_
    
    return sorted(zip(crops, probabilities), key=lambda x: x[1], reverse=True)

def match_crop_data(recommended_crops, yield_df, price_columns, crop_prices):
    """Match recommended crops with yield and price data."""
    crop_data = {}
    
    for crop_name, probability in recommended_crops:
        # Convert to uppercase for matching with ICRISAT columns
        crop_upper = crop_name.upper()
        
        # Find matching price column
        matching_columns = [col for col in price_columns if crop_upper in col]
        if not matching_columns:
            continue
            
        # Get yield data
        yield_values = yield_df[yield_df['Commodity'].str.lower() == crop_name.lower()]['Yield_Quintals_Per_Hectare'].values
        if len(yield_values) == 0:
            continue
            
        # Get the crop name from the price column
        icrisat_crop_name = matching_columns[0].split(' HARVEST')[0].strip()
        
        crop_data[icrisat_crop_name] = {
            'yield': yield_values[0],
            'price': crop_prices[icrisat_crop_name],
            'probability': probability
        }
    
    return crop_data

def generate_crop_combinations(crop_data, total_area=100):
    """Generate all possible combinations of crops with fixed area allocation."""
    combinations = []
    
    # Set fixed areas as per screenshot (1 ha for one crop, rest for the other)
    small_area = 1
    large_area = total_area - small_area
    
    # Generate all possible permutations of two crops
    for crop1, crop2 in itertools.permutations(crop_data.keys(), 2):
        # Calculate revenue
        revenue = (small_area * crop_data[crop1]['yield'] * crop_data[crop1]['price']) + \
                 (large_area * crop_data[crop2]['yield'] * crop_data[crop2]['price'])
        
        combinations.append({
            'crop1': crop1,
            'area1': small_area,
            'crop2': crop2,
            'area2': large_area,
            'revenue': revenue
        })
    
    # Sort by revenue in descending order
    combinations.sort(key=lambda x: x['revenue'], reverse=True)
    return combinations[:5]  # Return top 5 combinations

def main():
    # Input farm conditions and total land area
    farm_conditions = [
        float(input(f"Enter {param}: ")) for param in 
        ['N (kg/ha)', 'P (kg/ha)', 'K (kg/ha)', 'Temperature (°C)', 
         'Humidity (%)', 'pH', 'Rainfall (mm)']
    ]
    total_area = float(input("Enter total available area (hectares): "))
    
    # Get crop prices and price columns
    crop_prices, price_columns = preprocess_data()
    
    # Get crop recommendations based on farm conditions
    recommended_crops = recommend_crops(farm_conditions)
    
    # Match recommended crops with yield and price data
    crop_data = match_crop_data(recommended_crops[:10], yield_df, price_columns, crop_prices)
    
    # Generate crop combinations for maximum revenue
    combinations = generate_crop_combinations(crop_data, total_area)
    
    # Display results in the format shown in the screenshot
    print("\nTop 5 Crop Combinations for Maximum Income:")
    for i, combo in enumerate(combinations, 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Estimated Income: ₹{combo['revenue']:,.2f}")

if __name__ == "__main__":
    main()
# Out:
# Top 5 Crop Combinations for Maximum Income:
# 1. RICE HARVEST PRICE (Rs per Quintal) (1 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (99.0 ha)
#    Estimated Income: ₹595,163.45
# 2. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (1 ha) + RICE HARVEST PRICE (Rs per Quintal) (99.0 ha)
#    Estimated Income: ₹560,514.72
# c:\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import itertools

# Load datasets
crop_df = pd.read_csv('data.csv')
yield_df = pd.read_csv('commodity_yield.csv')
icrisat_df = pd.read_csv('ICRISAT-District Level Data.csv')

def preprocess_data():
    """Extract crop price data from ICRISAT dataset."""
    price_columns = [col for col in icrisat_df.columns if 'HARVEST PRICE' in col]
    crop_prices = {}
    
    for column in price_columns:
        crop_name = column.split(' HARVEST')[0].strip()
        crop_prices[crop_name] = icrisat_df[column].mean()
    
    return crop_prices, price_columns

def recommend_crops(farm_conditions):
    """Recommend crops using KNN based on farm conditions."""
    X = crop_df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
    y = crop_df['label']
    
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X, y)
    
    probabilities = knn.predict_proba([farm_conditions])[0]
    crops = knn.classes_
    
    return sorted(zip(crops, probabilities), key=lambda x: x[1], reverse=True)

def match_crop_data(recommended_crops, yield_df, price_columns, crop_prices):
    """Match recommended crops with yield and price data."""
    crop_data = {}
    
    for crop_name, probability in recommended_crops:
        # Convert to uppercase for matching with ICRISAT columns
        crop_upper = crop_name.upper()
        
        # Find matching price column
        matching_columns = [col for col in price_columns if crop_upper in col]
        if not matching_columns:
            continue
            
        # Get yield data
        yield_values = yield_df[yield_df['Commodity'].str.lower() == crop_name.lower()]['Yield_Quintals_Per_Hectare'].values
        if len(yield_values) == 0:
            continue
            
        # Get the crop name from the price column
        icrisat_crop_name = matching_columns[0].split(' HARVEST')[0].strip()
        
        crop_data[icrisat_crop_name] = {
            'yield': yield_values[0],
            'price': crop_prices[icrisat_crop_name],
            'probability': probability
        }
    
    return crop_data

def generate_crop_combinations(crop_data, total_area=100):
    """Generate combinations of crops with varying area allocations."""
    combinations = []
    
    # Get all pairs of crops
    crop_pairs = list(itertools.permutations(crop_data.keys(), 2))
    
    # Try different area allocations with step size of 10
    for area1 in range(0, int(total_area + 1), 10):
        area2 = total_area - area1
        
        for crop1, crop2 in crop_pairs:
            # Calculate revenue
            revenue = (area1 * crop_data[crop1]['yield'] * crop_data[crop1]['price']) + \
                     (area2 * crop_data[crop2]['yield'] * crop_data[crop2]['price'])
            
            combinations.append({
                'crop1': crop1,
                'area1': area1,
                'crop2': crop2,
                'area2': area2,
                'revenue': revenue
            })
    
    # Sort by revenue in descending order
    combinations.sort(key=lambda x: x['revenue'], reverse=True)
    return combinations

def main():
    # Input farm conditions and total land area
    farm_conditions = [
        float(input(f"Enter {param}: ")) for param in 
        ['N (kg/ha)', 'P (kg/ha)', 'K (kg/ha)', 'Temperature (°C)', 
         'Humidity (%)', 'pH', 'Rainfall (mm)']
    ]
    total_area = float(input("Enter total available area (hectares): "))
    
    # Get crop prices and price columns
    crop_prices, price_columns = preprocess_data()
    
    # Get crop recommendations based on farm conditions
    recommended_crops = recommend_crops(farm_conditions)
    
    # Match recommended crops with yield and price data
    crop_data = match_crop_data(recommended_crops[:10], yield_df, price_columns, crop_prices)
    
    # Generate crop combinations with varying area allocations
    combinations = generate_crop_combinations(crop_data, total_area)
    
    # Store all revenues in an array
    revenues = [combo['revenue'] for combo in combinations]
    
    # Find the maximum revenue
    max_revenue = max(revenues) if revenues else 0
    
    # Find the combination(s) that give the maximum revenue
    max_combinations = [combo for combo in combinations if combo['revenue'] == max_revenue]
    
    # Display all tested combinations
    print("\nAll Tested Crop Combinations:")
    for i, combo in enumerate(combinations, 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Estimated Income: ₹{combo['revenue']:,.2f}")
    
    # Display the top 5 combinations
    print("\nTop 5 Crop Combinations for Maximum Income:")
    for i, combo in enumerate(combinations[:5], 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Estimated Income: ₹{combo['revenue']:,.2f}")
    
    # Display the combination(s) with maximum revenue
    print("\nCombination(s) with Maximum Revenue:")
    for i, combo in enumerate(max_combinations, 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Maximum Estimated Income: ₹{combo['revenue']:,.2f}")

if __name__ == "__main__":
    main()
# Out:
# All Tested Crop Combinations:
# 1. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (100.0 ha)
#    Estimated Income: ₹595,517.01
# 2. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (100 ha) + RICE HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Estimated Income: ₹595,517.01
# 3. RICE HARVEST PRICE (Rs per Quintal) (10 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (90.0 ha)
#    Estimated Income: ₹591,981.42
# 4. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (90 ha) + RICE HARVEST PRICE (Rs per Quintal) (10.0 ha)
#    Estimated Income: ₹591,981.42
# 5. RICE HARVEST PRICE (Rs per Quintal) (20 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹588,445.84
# 6. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (80 ha) + RICE HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹588,445.84
# 7. RICE HARVEST PRICE (Rs per Quintal) (30 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (70.0 ha)
#    Estimated Income: ₹584,910.25
# 8. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (70 ha) + RICE HARVEST PRICE (Rs per Quintal) (30.0 ha)
#    Estimated Income: ₹584,910.25
# 9. RICE HARVEST PRICE (Rs per Quintal) (40 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (60.0 ha)
#    Estimated Income: ₹581,374.67
# 10. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (60 ha) + RICE HARVEST PRICE (Rs per Quintal) (40.0 ha)
#    Estimated Income: ₹581,374.67
# 11. RICE HARVEST PRICE (Rs per Quintal) (50 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (50.0 ha)
#    Estimated Income: ₹577,839.08
# 12. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (50 ha) + RICE HARVEST PRICE (Rs per Quintal) (50.0 ha)
#    Estimated Income: ₹577,839.08
# 13. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (40 ha) + RICE HARVEST PRICE (Rs per Quintal) (60.0 ha)
#    Estimated Income: ₹574,303.50
# 14. RICE HARVEST PRICE (Rs per Quintal) (60 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (40.0 ha)
#    Estimated Income: ₹574,303.50
# 15. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (30 ha) + RICE HARVEST PRICE (Rs per Quintal) (70.0 ha)
#    Estimated Income: ₹570,767.91
# 16. RICE HARVEST PRICE (Rs per Quintal) (70 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (30.0 ha)
#    Estimated Income: ₹570,767.91
# 17. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (20 ha) + RICE HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹567,232.33
# 18. RICE HARVEST PRICE (Rs per Quintal) (80 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹567,232.33
# 19. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (10 ha) + RICE HARVEST PRICE (Rs per Quintal) (90.0 ha)
#    Estimated Income: ₹563,696.74
# 20. RICE HARVEST PRICE (Rs per Quintal) (90 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (10.0 ha)
#    Estimated Income: ₹563,696.74
# 21. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + RICE HARVEST PRICE (Rs per Quintal) (100.0 ha)
#    Estimated Income: ₹560,161.16
# 22. RICE HARVEST PRICE (Rs per Quintal) (100 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Estimated Income: ₹560,161.16
#
# Top 5 Crop Combinations for Maximum Income:
# 1. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (100.0 ha)
#    Estimated Income: ₹595,517.01
# 2. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (100 ha) + RICE HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Estimated Income: ₹595,517.01
# 3. RICE HARVEST PRICE (Rs per Quintal) (10 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (90.0 ha)
#    Estimated Income: ₹591,981.42
# 4. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (90 ha) + RICE HARVEST PRICE (Rs per Quintal) (10.0 ha)
#    Estimated Income: ₹591,981.42
# 5. RICE HARVEST PRICE (Rs per Quintal) (20 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹588,445.84
#
# Combination(s) with Maximum Revenue:
# 1. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (100.0 ha)
#    Maximum Estimated Income: ₹595,517.01
# 2. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (100 ha) + RICE HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Maximum Estimated Income: ₹595,517.01
# c:\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import itertools

# Load datasets
crop_df = pd.read_csv('data.csv')
yield_df = pd.read_csv('commodity_yield.csv')
icrisat_df = pd.read_csv('ICRISAT-District Level Data.csv')
price_df = pd.read_csv('pricesdataset.csv')

def preprocess_data():
    """Extract crop price data from ICRISAT dataset."""
    price_columns = [col for col in icrisat_df.columns if 'HARVEST PRICE' in col]
    crop_prices = {}
    
    for column in price_columns:
        crop_name = column.split(' HARVEST')[0].strip()
        crop_prices[crop_name] = icrisat_df[column].mean()
    
    return crop_prices, price_columns

def get_suitable_crops(n, p, k, temp, humidity, ph, rainfall):
    """Find suitable crops based on soil parameters using KNN."""
    X = crop_df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
    y = crop_df['label']
    
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X, y)
    
    farm_conditions = [n, p, k, temp, humidity, ph, rainfall]
    probabilities = knn.predict_proba([farm_conditions])[0]
    crops = knn.classes_
    
    # Return all crops with their suitability probability
    return sorted(zip(crops, probabilities), key=lambda x: x[1], reverse=True)

def match_crop_data(suitable_crops, yield_df, price_columns, crop_prices):
    """Match suitable crops with yield and price data."""
    crop_data = {}
    
    for crop_name, probability in suitable_crops:
        # Convert to uppercase for matching with ICRISAT columns
        crop_upper = crop_name.upper()
        
        # Find matching price column
        matching_columns = [col for col in price_columns if crop_upper in col]
        if not matching_columns:
            continue
            
        # Get yield data
        yield_values = yield_df[yield_df['Commodity'].str.lower() == crop_name.lower()]['Yield_Quintals_Per_Hectare'].values
        if len(yield_values) == 0:
            continue
            
        # Get the crop name from the price column
        icrisat_crop_name = matching_columns[0].split(' HARVEST')[0].strip()
        
        crop_data[icrisat_crop_name] = {
            'yield': yield_values[0],
            'price': crop_prices[icrisat_crop_name],
            'probability': probability
        }
    
    return crop_data

def generate_crop_combinations(crop_data, total_area=100, step_size=5):
    """Generate all crop combinations with variable area allocations."""
    combinations = []
    
    # Get all pairs of crops
    crop_pairs = list(itertools.permutations(crop_data.keys(), 2))
    
    # Try different area allocations with specified step size
    for area1 in range(0, int(total_area + 1), step_size):
        area2 = total_area - area1
        
        for crop1, crop2 in crop_pairs:
            # Calculate revenue
            revenue = (area1 * crop_data[crop1]['yield'] * crop_data[crop1]['price']) + \
                     (area2 * crop_data[crop2]['yield'] * crop_data[crop2]['price'])
            
            combinations.append({
                'crop1': crop1,
                'area1': area1,
                'crop2': crop2,
                'area2': area2,
                'revenue': revenue,
                'crop1_prob': crop_data[crop1]['probability'],
                'crop2_prob': crop_data[crop2]['probability']
            })
    
    # Sort by revenue in descending order
    combinations.sort(key=lambda x: x['revenue'], reverse=True)
    return combinations

def main():
    # Input farm conditions and total land area
    print("Enter soil and climate parameters:")
    n = float(input("Enter Nitrogen (N) content (kg/ha): "))
    p = float(input("Enter Phosphorus (P) content (kg/ha): "))
    k = float(input("Enter Potassium (K) content (kg/ha): "))
    temp = float(input("Enter Temperature (°C): "))
    humidity = float(input("Enter Humidity (%): "))
    ph = float(input("Enter pH: "))
    rainfall = float(input("Enter Rainfall (mm): "))
    
    total_area = float(input("Enter total available area (hectares): "))
    step_size = int(input("Enter step size for area allocation (5-10 recommended): "))
    
    # Preprocess data
    crop_prices, price_columns = preprocess_data()
    
    # Get suitable crops based on soil parameters
    suitable_crops = get_suitable_crops(n, p, k, temp, humidity, ph, rainfall)
    
    print("\nTop 10 Recommended Crops Based on Soil Parameters:")
    for i, (crop, prob) in enumerate(suitable_crops[:10], 1):
        print(f"{i}. {crop.capitalize()} (Suitability: {prob:.2%})")
    
    # Match suitable crops with yield and price data
    crop_data = match_crop_data(suitable_crops, yield_df, price_columns, crop_prices)
    
    # Generate crop combinations with varying area allocations
    combinations = generate_crop_combinations(crop_data, total_area, step_size)
    
    # Store all revenues
    revenues = [combo['revenue'] for combo in combinations]
    
    # Find the maximum revenue
    max_revenue = max(revenues) if revenues else 0
    
    # Find the combination(s) that give the maximum revenue
    max_combinations = [combo for combo in combinations if combo['revenue'] == max_revenue]
    
    # Display all tested combinations
    print("\nAll Tested Crop Combinations:")
    for i, combo in enumerate(combinations, 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Estimated Income: ₹{combo['revenue']:,.2f}")
    
    # Display the top 5 combinations
    print("\nTop 5 Crop Combinations for Maximum Income:")
    for i, combo in enumerate(combinations[:5], 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Estimated Income: ₹{combo['revenue']:,.2f}")
    
    # Display the combination(s) with maximum revenue
    print("\nOptimal Crop Combination(s) for Maximum Revenue:")
    for i, combo in enumerate(max_combinations, 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Maximum Estimated Income: ₹{combo['revenue']:,.2f}")
        print(f"   Soil Suitability: {combo['crop1']} ({combo['crop1_prob']:.2%}), {combo['crop2']} ({combo['crop2_prob']:.2%})")

if __name__ == "__main__":
    main()
# Out:
# Enter soil and climate parameters:
#
# Top 10 Recommended Crops Based on Soil Parameters:
# 1. Rice (Suitability: 100.00%)
# 2. Apple (Suitability: 0.00%)
# 3. Banana (Suitability: 0.00%)
# 4. Blackgram (Suitability: 0.00%)
# 5. Chickpea (Suitability: 0.00%)
# 6. Coconut (Suitability: 0.00%)
# 7. Coffee (Suitability: 0.00%)
# 8. Cotton (Suitability: 0.00%)
# 9. Grapes (Suitability: 0.00%)
# 10. Jute (Suitability: 0.00%)
#
# All Tested Crop Combinations:
# 1. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (1000.0 ha)
#    Estimated Income: ₹7,237,727.71
# 2. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (1000.0 ha)
#    Estimated Income: ₹7,237,727.71
# 3. MAIZE HARVEST PRICE (Rs per Quintal) (994 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (6.0 ha)
#    Estimated Income: ₹7,230,032.36
# 4. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (7 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (993.0 ha)
#    Estimated Income: ₹7,228,749.80
# 5. MAIZE HARVEST PRICE (Rs per Quintal) (994 ha) + RICE HARVEST PRICE (Rs per Quintal) (6.0 ha)
#    Estimated Income: ₹7,227,911.01
# 6. RICE HARVEST PRICE (Rs per Quintal) (7 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (993.0 ha)
#    Estimated Income: ₹7,226,274.89
# 7. MAIZE HARVEST PRICE (Rs per Quintal) (987 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (13.0 ha)
#    Estimated Income: ₹7,221,054.46
# 8. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (14 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (986.0 ha)
#    Estimated Income: ₹7,219,771.90
# 9. MAIZE HARVEST PRICE (Rs per Quintal) (987 ha) + RICE HARVEST PRICE (Rs per Quintal) (13.0 ha)
#    Estimated Income: ₹7,216,458.20
# 10. RICE HARVEST PRICE (Rs per Quintal) (14 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (986.0 ha)
#    Estimated Income: ₹7,214,822.08
# 11. MAIZE HARVEST PRICE (Rs per Quintal) (980 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹7,212,076.55
# 12. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (21 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (979.0 ha)
#    Estimated Income: ₹7,210,794.00
# 13. MAIZE HARVEST PRICE (Rs per Quintal) (980 ha) + RICE HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹7,205,005.38
# 14. RICE HARVEST PRICE (Rs per Quintal) (21 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (979.0 ha)
#    Estimated Income: ₹7,203,369.27
# 15. MAIZE HARVEST PRICE (Rs per Quintal) (973 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (27.0 ha)
#    Estimated Income: ₹7,203,098.65
# 16. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (28 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (972.0 ha)
#    Estimated Income: ₹7,201,816.09
# 17. MAIZE HARVEST PRICE (Rs per Quintal) (966 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (34.0 ha)
#    Estimated Income: ₹7,194,120.75
# 18. MAIZE HARVEST PRICE (Rs per Quintal) (973 ha) + RICE HARVEST PRICE (Rs per Quintal) (27.0 ha)
#    Estimated Income: ₹7,193,552.57
# 19. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (35 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (965.0 ha)
#    Estimated Income: ₹7,192,838.19
# 20. RICE HARVEST PRICE (Rs per Quintal) (28 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (972.0 ha)
#    Estimated Income: ₹7,191,916.45
# 21. MAIZE HARVEST PRICE (Rs per Quintal) (959 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (41.0 ha)
#    Estimated Income: ₹7,185,142.84
# 22. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (42 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (958.0 ha)
#    Estimated Income: ₹7,183,860.29
# 23. MAIZE HARVEST PRICE (Rs per Quintal) (966 ha) + RICE HARVEST PRICE (Rs per Quintal) (34.0 ha)
#    Estimated Income: ₹7,182,099.76
# 24. RICE HARVEST PRICE (Rs per Quintal) (35 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (965.0 ha)
#    Estimated Income: ₹7,180,463.64
# 25. MAIZE HARVEST PRICE (Rs per Quintal) (952 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (48.0 ha)
#    Estimated Income: ₹7,176,164.94
# 26. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (49 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (951.0 ha)
#    Estimated Income: ₹7,174,882.38
# 27. MAIZE HARVEST PRICE (Rs per Quintal) (959 ha) + RICE HARVEST PRICE (Rs per Quintal) (41.0 ha)
#    Estimated Income: ₹7,170,646.95
# 28. RICE HARVEST PRICE (Rs per Quintal) (42 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (958.0 ha)
#    Estimated Income: ₹7,169,010.83
# 29. MAIZE HARVEST PRICE (Rs per Quintal) (945 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (55.0 ha)
#    Estimated Income: ₹7,167,187.04
# 30. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (56 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (944.0 ha)
#    Estimated Income: ₹7,165,904.48
# 31. MAIZE HARVEST PRICE (Rs per Quintal) (952 ha) + RICE HARVEST PRICE (Rs per Quintal) (48.0 ha)
#    Estimated Income: ₹7,159,194.13
# 32. MAIZE HARVEST PRICE (Rs per Quintal) (938 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (62.0 ha)
#    Estimated Income: ₹7,158,209.13
# 33. RICE HARVEST PRICE (Rs per Quintal) (49 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (951.0 ha)
#    Estimated Income: ₹7,157,558.02
# 34. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (63 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (937.0 ha)
#    Estimated Income: ₹7,156,926.57
# 35. MAIZE HARVEST PRICE (Rs per Quintal) (931 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (69.0 ha)
#    Estimated Income: ₹7,149,231.23
# 36. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (70 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (930.0 ha)
#    Estimated Income: ₹7,147,948.67
# 37. MAIZE HARVEST PRICE (Rs per Quintal) (945 ha) + RICE HARVEST PRICE (Rs per Quintal) (55.0 ha)
#    Estimated Income: ₹7,147,741.32
# 38. RICE HARVEST PRICE (Rs per Quintal) (56 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (944.0 ha)
#    Estimated Income: ₹7,146,105.20
# 39. MAIZE HARVEST PRICE (Rs per Quintal) (924 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (76.0 ha)
#    Estimated Income: ₹7,140,253.33
# 40. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (77 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (923.0 ha)
#    Estimated Income: ₹7,138,970.77
# 41. MAIZE HARVEST PRICE (Rs per Quintal) (938 ha) + RICE HARVEST PRICE (Rs per Quintal) (62.0 ha)
#    Estimated Income: ₹7,136,288.51
# 42. RICE HARVEST PRICE (Rs per Quintal) (63 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (937.0 ha)
#    Estimated Income: ₹7,134,652.39
# 43. MAIZE HARVEST PRICE (Rs per Quintal) (917 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (83.0 ha)
#    Estimated Income: ₹7,131,275.42
# 44. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (84 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (916.0 ha)
#    Estimated Income: ₹7,129,992.86
# 45. MAIZE HARVEST PRICE (Rs per Quintal) (931 ha) + RICE HARVEST PRICE (Rs per Quintal) (69.0 ha)
#    Estimated Income: ₹7,124,835.69
# 46. RICE HARVEST PRICE (Rs per Quintal) (70 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (930.0 ha)
#    Estimated Income: ₹7,123,199.58
# 47. MAIZE HARVEST PRICE (Rs per Quintal) (910 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (90.0 ha)
#    Estimated Income: ₹7,122,297.52
# 48. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (91 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (909.0 ha)
#    Estimated Income: ₹7,121,014.96
# 49. MAIZE HARVEST PRICE (Rs per Quintal) (924 ha) + RICE HARVEST PRICE (Rs per Quintal) (76.0 ha)
#    Estimated Income: ₹7,113,382.88
# 50. MAIZE HARVEST PRICE (Rs per Quintal) (903 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (97.0 ha)
#    Estimated Income: ₹7,113,319.61
# 51. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (98 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (902.0 ha)
#    Estimated Income: ₹7,112,037.06
# 52. RICE HARVEST PRICE (Rs per Quintal) (77 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (923.0 ha)
#    Estimated Income: ₹7,111,746.76
# 53. MAIZE HARVEST PRICE (Rs per Quintal) (896 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹7,104,341.71
# 54. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (105 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (895.0 ha)
#    Estimated Income: ₹7,103,059.15
# 55. MAIZE HARVEST PRICE (Rs per Quintal) (917 ha) + RICE HARVEST PRICE (Rs per Quintal) (83.0 ha)
#    Estimated Income: ₹7,101,930.07
# 56. RICE HARVEST PRICE (Rs per Quintal) (84 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (916.0 ha)
#    Estimated Income: ₹7,100,293.95
# 57. MAIZE HARVEST PRICE (Rs per Quintal) (889 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (111.0 ha)
#    Estimated Income: ₹7,095,363.81
# 58. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (112 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (888.0 ha)
#    Estimated Income: ₹7,094,081.25
# 59. MAIZE HARVEST PRICE (Rs per Quintal) (910 ha) + RICE HARVEST PRICE (Rs per Quintal) (90.0 ha)
#    Estimated Income: ₹7,090,477.26
# 60. RICE HARVEST PRICE (Rs per Quintal) (91 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (909.0 ha)
#    Estimated Income: ₹7,088,841.14
# 61. MAIZE HARVEST PRICE (Rs per Quintal) (882 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (118.0 ha)
#    Estimated Income: ₹7,086,385.90
# 62. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (119 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (881.0 ha)
#    Estimated Income: ₹7,085,103.35
# 63. MAIZE HARVEST PRICE (Rs per Quintal) (903 ha) + RICE HARVEST PRICE (Rs per Quintal) (97.0 ha)
#    Estimated Income: ₹7,079,024.44
# 64. MAIZE HARVEST PRICE (Rs per Quintal) (875 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (125.0 ha)
#    Estimated Income: ₹7,077,408.00
# 65. RICE HARVEST PRICE (Rs per Quintal) (98 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (902.0 ha)
#    Estimated Income: ₹7,077,388.33
# 66. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (126 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (874.0 ha)
#    Estimated Income: ₹7,076,125.44
# 67. MAIZE HARVEST PRICE (Rs per Quintal) (868 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (132.0 ha)
#    Estimated Income: ₹7,068,430.10
# 68. MAIZE HARVEST PRICE (Rs per Quintal) (896 ha) + RICE HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹7,067,571.63
# 69. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (133 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (867.0 ha)
#    Estimated Income: ₹7,067,147.54
# 70. RICE HARVEST PRICE (Rs per Quintal) (105 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (895.0 ha)
#    Estimated Income: ₹7,065,935.51
# 71. MAIZE HARVEST PRICE (Rs per Quintal) (861 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (139.0 ha)
#    Estimated Income: ₹7,059,452.19
# 72. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (140 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (860.0 ha)
#    Estimated Income: ₹7,058,169.64
# 73. MAIZE HARVEST PRICE (Rs per Quintal) (889 ha) + RICE HARVEST PRICE (Rs per Quintal) (111.0 ha)
#    Estimated Income: ₹7,056,118.82
# 74. RICE HARVEST PRICE (Rs per Quintal) (112 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (888.0 ha)
#    Estimated Income: ₹7,054,482.70
# 75. MAIZE HARVEST PRICE (Rs per Quintal) (854 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (146.0 ha)
#    Estimated Income: ₹7,050,474.29
# 76. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (147 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (853.0 ha)
#    Estimated Income: ₹7,049,191.73
# 77. MAIZE HARVEST PRICE (Rs per Quintal) (882 ha) + RICE HARVEST PRICE (Rs per Quintal) (118.0 ha)
#    Estimated Income: ₹7,044,666.00
# 78. RICE HARVEST PRICE (Rs per Quintal) (119 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (881.0 ha)
#    Estimated Income: ₹7,043,029.89
# 79. MAIZE HARVEST PRICE (Rs per Quintal) (847 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (153.0 ha)
#    Estimated Income: ₹7,041,496.39
# 80. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (154 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (846.0 ha)
#    Estimated Income: ₹7,040,213.83
# 81. MAIZE HARVEST PRICE (Rs per Quintal) (875 ha) + RICE HARVEST PRICE (Rs per Quintal) (125.0 ha)
#    Estimated Income: ₹7,033,213.19
# 82. MAIZE HARVEST PRICE (Rs per Quintal) (840 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (160.0 ha)
#    Estimated Income: ₹7,032,518.48
# 83. RICE HARVEST PRICE (Rs per Quintal) (126 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (874.0 ha)
#    Estimated Income: ₹7,031,577.07
# 84. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (161 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (839.0 ha)
#    Estimated Income: ₹7,031,235.92
# 85. MAIZE HARVEST PRICE (Rs per Quintal) (833 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (167.0 ha)
#    Estimated Income: ₹7,023,540.58
# 86. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (168 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (832.0 ha)
#    Estimated Income: ₹7,022,258.02
# 87. MAIZE HARVEST PRICE (Rs per Quintal) (868 ha) + RICE HARVEST PRICE (Rs per Quintal) (132.0 ha)
#    Estimated Income: ₹7,021,760.38
# 88. RICE HARVEST PRICE (Rs per Quintal) (133 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (867.0 ha)
#    Estimated Income: ₹7,020,124.26
# 89. MAIZE HARVEST PRICE (Rs per Quintal) (826 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (174.0 ha)
#    Estimated Income: ₹7,014,562.68
# 90. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (175 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (825.0 ha)
#    Estimated Income: ₹7,013,280.12
# 91. MAIZE HARVEST PRICE (Rs per Quintal) (861 ha) + RICE HARVEST PRICE (Rs per Quintal) (139.0 ha)
#    Estimated Income: ₹7,010,307.56
# 92. RICE HARVEST PRICE (Rs per Quintal) (140 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (860.0 ha)
#    Estimated Income: ₹7,008,671.45
# 93. MAIZE HARVEST PRICE (Rs per Quintal) (819 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (181.0 ha)
#    Estimated Income: ₹7,005,584.77
# 94. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (182 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (818.0 ha)
#    Estimated Income: ₹7,004,302.21
# 95. MAIZE HARVEST PRICE (Rs per Quintal) (854 ha) + RICE HARVEST PRICE (Rs per Quintal) (146.0 ha)
#    Estimated Income: ₹6,998,854.75
# 96. RICE HARVEST PRICE (Rs per Quintal) (147 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (853.0 ha)
#    Estimated Income: ₹6,997,218.64
# 97. MAIZE HARVEST PRICE (Rs per Quintal) (812 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹6,996,606.87
# 98. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (189 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (811.0 ha)
#    Estimated Income: ₹6,995,324.31
# 99. MAIZE HARVEST PRICE (Rs per Quintal) (805 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (195.0 ha)
#    Estimated Income: ₹6,987,628.96
# 100. MAIZE HARVEST PRICE (Rs per Quintal) (847 ha) + RICE HARVEST PRICE (Rs per Quintal) (153.0 ha)
#    Estimated Income: ₹6,987,401.94
# 101. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (196 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (804.0 ha)
#    Estimated Income: ₹6,986,346.41
# 102. RICE HARVEST PRICE (Rs per Quintal) (154 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (846.0 ha)
#    Estimated Income: ₹6,985,765.82
# 103. MAIZE HARVEST PRICE (Rs per Quintal) (798 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (202.0 ha)
#    Estimated Income: ₹6,978,651.06
# 104. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (203 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (797.0 ha)
#    Estimated Income: ₹6,977,368.50
# 105. MAIZE HARVEST PRICE (Rs per Quintal) (840 ha) + RICE HARVEST PRICE (Rs per Quintal) (160.0 ha)
#    Estimated Income: ₹6,975,949.13
# 106. RICE HARVEST PRICE (Rs per Quintal) (161 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (839.0 ha)
#    Estimated Income: ₹6,974,313.01
# 107. MAIZE HARVEST PRICE (Rs per Quintal) (791 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (209.0 ha)
#    Estimated Income: ₹6,969,673.16
# 108. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (210 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (790.0 ha)
#    Estimated Income: ₹6,968,390.60
# 109. MAIZE HARVEST PRICE (Rs per Quintal) (833 ha) + RICE HARVEST PRICE (Rs per Quintal) (167.0 ha)
#    Estimated Income: ₹6,964,496.31
# 110. RICE HARVEST PRICE (Rs per Quintal) (168 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (832.0 ha)
#    Estimated Income: ₹6,962,860.20
# 111. MAIZE HARVEST PRICE (Rs per Quintal) (784 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (216.0 ha)
#    Estimated Income: ₹6,960,695.25
# 112. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (217 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (783.0 ha)
#    Estimated Income: ₹6,959,412.70
# 113. MAIZE HARVEST PRICE (Rs per Quintal) (826 ha) + RICE HARVEST PRICE (Rs per Quintal) (174.0 ha)
#    Estimated Income: ₹6,953,043.50
# 114. MAIZE HARVEST PRICE (Rs per Quintal) (777 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (223.0 ha)
#    Estimated Income: ₹6,951,717.35
# 115. RICE HARVEST PRICE (Rs per Quintal) (175 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (825.0 ha)
#    Estimated Income: ₹6,951,407.38
# 116. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (224 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (776.0 ha)
#    Estimated Income: ₹6,950,434.79
# 117. MAIZE HARVEST PRICE (Rs per Quintal) (770 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (230.0 ha)
#    Estimated Income: ₹6,942,739.45
# 118. MAIZE HARVEST PRICE (Rs per Quintal) (819 ha) + RICE HARVEST PRICE (Rs per Quintal) (181.0 ha)
#    Estimated Income: ₹6,941,590.69
# 119. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (231 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (769.0 ha)
#    Estimated Income: ₹6,941,456.89
# 120. RICE HARVEST PRICE (Rs per Quintal) (182 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (818.0 ha)
#    Estimated Income: ₹6,939,954.57
# 121. MAIZE HARVEST PRICE (Rs per Quintal) (763 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (237.0 ha)
#    Estimated Income: ₹6,933,761.54
# 122. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (238 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (762.0 ha)
#    Estimated Income: ₹6,932,478.99
# 123. MAIZE HARVEST PRICE (Rs per Quintal) (812 ha) + RICE HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹6,930,137.87
# 124. RICE HARVEST PRICE (Rs per Quintal) (189 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (811.0 ha)
#    Estimated Income: ₹6,928,501.76
# 125. MAIZE HARVEST PRICE (Rs per Quintal) (756 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (244.0 ha)
#    Estimated Income: ₹6,924,783.64
# 126. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (245 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (755.0 ha)
#    Estimated Income: ₹6,923,501.08
# 127. MAIZE HARVEST PRICE (Rs per Quintal) (805 ha) + RICE HARVEST PRICE (Rs per Quintal) (195.0 ha)
#    Estimated Income: ₹6,918,685.06
# 128. RICE HARVEST PRICE (Rs per Quintal) (196 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (804.0 ha)
#    Estimated Income: ₹6,917,048.95
# 129. MAIZE HARVEST PRICE (Rs per Quintal) (749 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (251.0 ha)
#    Estimated Income: ₹6,915,805.74
# 130. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (252 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (748.0 ha)
#    Estimated Income: ₹6,914,523.18
# 131. MAIZE HARVEST PRICE (Rs per Quintal) (798 ha) + RICE HARVEST PRICE (Rs per Quintal) (202.0 ha)
#    Estimated Income: ₹6,907,232.25
# 132. MAIZE HARVEST PRICE (Rs per Quintal) (742 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (258.0 ha)
#    Estimated Income: ₹6,906,827.83
# 133. RICE HARVEST PRICE (Rs per Quintal) (203 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (797.0 ha)
#    Estimated Income: ₹6,905,596.13
# 134. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (259 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (741.0 ha)
#    Estimated Income: ₹6,905,545.28
# 135. MAIZE HARVEST PRICE (Rs per Quintal) (735 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (265.0 ha)
#    Estimated Income: ₹6,897,849.93
# 136. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (266 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (734.0 ha)
#    Estimated Income: ₹6,896,567.37
# 137. MAIZE HARVEST PRICE (Rs per Quintal) (791 ha) + RICE HARVEST PRICE (Rs per Quintal) (209.0 ha)
#    Estimated Income: ₹6,895,779.44
# 138. RICE HARVEST PRICE (Rs per Quintal) (210 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (790.0 ha)
#    Estimated Income: ₹6,894,143.32
# 139. MAIZE HARVEST PRICE (Rs per Quintal) (728 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (272.0 ha)
#    Estimated Income: ₹6,888,872.03
# 140. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (273 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (727.0 ha)
#    Estimated Income: ₹6,887,589.47
# 141. MAIZE HARVEST PRICE (Rs per Quintal) (784 ha) + RICE HARVEST PRICE (Rs per Quintal) (216.0 ha)
#    Estimated Income: ₹6,884,326.62
# 142. RICE HARVEST PRICE (Rs per Quintal) (217 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (783.0 ha)
#    Estimated Income: ₹6,882,690.51
# 143. MAIZE HARVEST PRICE (Rs per Quintal) (721 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (279.0 ha)
#    Estimated Income: ₹6,879,894.12
# 144. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (280 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (720.0 ha)
#    Estimated Income: ₹6,878,611.56
# 145. MAIZE HARVEST PRICE (Rs per Quintal) (777 ha) + RICE HARVEST PRICE (Rs per Quintal) (223.0 ha)
#    Estimated Income: ₹6,872,873.81
# 146. RICE HARVEST PRICE (Rs per Quintal) (224 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (776.0 ha)
#    Estimated Income: ₹6,871,237.69
# 147. MAIZE HARVEST PRICE (Rs per Quintal) (714 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (286.0 ha)
#    Estimated Income: ₹6,870,916.22
# 148. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (287 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (713.0 ha)
#    Estimated Income: ₹6,869,633.66
# 149. MAIZE HARVEST PRICE (Rs per Quintal) (707 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (293.0 ha)
#    Estimated Income: ₹6,861,938.31
# 150. MAIZE HARVEST PRICE (Rs per Quintal) (770 ha) + RICE HARVEST PRICE (Rs per Quintal) (230.0 ha)
#    Estimated Income: ₹6,861,421.00
# 151. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (294 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (706.0 ha)
#    Estimated Income: ₹6,860,655.76
# 152. RICE HARVEST PRICE (Rs per Quintal) (231 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (769.0 ha)
#    Estimated Income: ₹6,859,784.88
# 153. MAIZE HARVEST PRICE (Rs per Quintal) (700 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (300.0 ha)
#    Estimated Income: ₹6,852,960.41
# 154. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (301 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (699.0 ha)
#    Estimated Income: ₹6,851,677.85
# 155. MAIZE HARVEST PRICE (Rs per Quintal) (763 ha) + RICE HARVEST PRICE (Rs per Quintal) (237.0 ha)
#    Estimated Income: ₹6,849,968.18
# 156. RICE HARVEST PRICE (Rs per Quintal) (238 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (762.0 ha)
#    Estimated Income: ₹6,848,332.07
# 157. MAIZE HARVEST PRICE (Rs per Quintal) (693 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (307.0 ha)
#    Estimated Income: ₹6,843,982.51
# 158. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (308 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (692.0 ha)
#    Estimated Income: ₹6,842,699.95
# 159. MAIZE HARVEST PRICE (Rs per Quintal) (756 ha) + RICE HARVEST PRICE (Rs per Quintal) (244.0 ha)
#    Estimated Income: ₹6,838,515.37
# 160. RICE HARVEST PRICE (Rs per Quintal) (245 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (755.0 ha)
#    Estimated Income: ₹6,836,879.26
# 161. MAIZE HARVEST PRICE (Rs per Quintal) (686 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (314.0 ha)
#    Estimated Income: ₹6,835,004.60
# 162. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (315 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (685.0 ha)
#    Estimated Income: ₹6,833,722.05
# 163. MAIZE HARVEST PRICE (Rs per Quintal) (749 ha) + RICE HARVEST PRICE (Rs per Quintal) (251.0 ha)
#    Estimated Income: ₹6,827,062.56
# 164. MAIZE HARVEST PRICE (Rs per Quintal) (679 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (321.0 ha)
#    Estimated Income: ₹6,826,026.70
# 165. RICE HARVEST PRICE (Rs per Quintal) (252 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (748.0 ha)
#    Estimated Income: ₹6,825,426.44
# 166. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (322 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (678.0 ha)
#    Estimated Income: ₹6,824,744.14
# 167. MAIZE HARVEST PRICE (Rs per Quintal) (672 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (328.0 ha)
#    Estimated Income: ₹6,817,048.80
# 168. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (329 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (671.0 ha)
#    Estimated Income: ₹6,815,766.24
# 169. MAIZE HARVEST PRICE (Rs per Quintal) (742 ha) + RICE HARVEST PRICE (Rs per Quintal) (258.0 ha)
#    Estimated Income: ₹6,815,609.75
# 170. RICE HARVEST PRICE (Rs per Quintal) (259 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (741.0 ha)
#    Estimated Income: ₹6,813,973.63
# 171. MAIZE HARVEST PRICE (Rs per Quintal) (665 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (335.0 ha)
#    Estimated Income: ₹6,808,070.89
# 172. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (336 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (664.0 ha)
#    Estimated Income: ₹6,806,788.34
# 173. MAIZE HARVEST PRICE (Rs per Quintal) (735 ha) + RICE HARVEST PRICE (Rs per Quintal) (265.0 ha)
#    Estimated Income: ₹6,804,156.93
# 174. RICE HARVEST PRICE (Rs per Quintal) (266 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (734.0 ha)
#    Estimated Income: ₹6,802,520.82
# 175. MAIZE HARVEST PRICE (Rs per Quintal) (658 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (342.0 ha)
#    Estimated Income: ₹6,799,092.99
# 176. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (343 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (657.0 ha)
#    Estimated Income: ₹6,797,810.43
# 177. MAIZE HARVEST PRICE (Rs per Quintal) (728 ha) + RICE HARVEST PRICE (Rs per Quintal) (272.0 ha)
#    Estimated Income: ₹6,792,704.12
# 178. RICE HARVEST PRICE (Rs per Quintal) (273 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (727.0 ha)
#    Estimated Income: ₹6,791,068.00
# 179. MAIZE HARVEST PRICE (Rs per Quintal) (651 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (349.0 ha)
#    Estimated Income: ₹6,790,115.09
# 180. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (350 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (650.0 ha)
#    Estimated Income: ₹6,788,832.53
# 181. MAIZE HARVEST PRICE (Rs per Quintal) (721 ha) + RICE HARVEST PRICE (Rs per Quintal) (279.0 ha)
#    Estimated Income: ₹6,781,251.31
# 182. MAIZE HARVEST PRICE (Rs per Quintal) (644 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (356.0 ha)
#    Estimated Income: ₹6,781,137.18
# 183. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (357 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (643.0 ha)
#    Estimated Income: ₹6,779,854.63
# 184. RICE HARVEST PRICE (Rs per Quintal) (280 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (720.0 ha)
#    Estimated Income: ₹6,779,615.19
# 185. MAIZE HARVEST PRICE (Rs per Quintal) (637 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (363.0 ha)
#    Estimated Income: ₹6,772,159.28
# 186. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (364 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (636.0 ha)
#    Estimated Income: ₹6,770,876.72
# 187. MAIZE HARVEST PRICE (Rs per Quintal) (714 ha) + RICE HARVEST PRICE (Rs per Quintal) (286.0 ha)
#    Estimated Income: ₹6,769,798.49
# 188. RICE HARVEST PRICE (Rs per Quintal) (287 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (713.0 ha)
#    Estimated Income: ₹6,768,162.38
# 189. MAIZE HARVEST PRICE (Rs per Quintal) (630 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (370.0 ha)
#    Estimated Income: ₹6,763,181.38
# 190. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (371 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (629.0 ha)
#    Estimated Income: ₹6,761,898.82
# 191. MAIZE HARVEST PRICE (Rs per Quintal) (707 ha) + RICE HARVEST PRICE (Rs per Quintal) (293.0 ha)
#    Estimated Income: ₹6,758,345.68
# 192. RICE HARVEST PRICE (Rs per Quintal) (294 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (706.0 ha)
#    Estimated Income: ₹6,756,709.57
# 193. MAIZE HARVEST PRICE (Rs per Quintal) (623 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (377.0 ha)
#    Estimated Income: ₹6,754,203.47
# 194. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (378 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (622.0 ha)
#    Estimated Income: ₹6,752,920.91
# 195. MAIZE HARVEST PRICE (Rs per Quintal) (700 ha) + RICE HARVEST PRICE (Rs per Quintal) (300.0 ha)
#    Estimated Income: ₹6,746,892.87
# 196. RICE HARVEST PRICE (Rs per Quintal) (301 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (699.0 ha)
#    Estimated Income: ₹6,745,256.75
# 197. MAIZE HARVEST PRICE (Rs per Quintal) (616 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (384.0 ha)
#    Estimated Income: ₹6,745,225.57
# 198. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (385 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (615.0 ha)
#    Estimated Income: ₹6,743,943.01
# 199. MAIZE HARVEST PRICE (Rs per Quintal) (609 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (391.0 ha)
#    Estimated Income: ₹6,736,247.67
# 200. MAIZE HARVEST PRICE (Rs per Quintal) (693 ha) + RICE HARVEST PRICE (Rs per Quintal) (307.0 ha)
#    Estimated Income: ₹6,735,440.06
# 201. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (392 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (608.0 ha)
#    Estimated Income: ₹6,734,965.11
# 202. RICE HARVEST PRICE (Rs per Quintal) (308 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (692.0 ha)
#    Estimated Income: ₹6,733,803.94
# 203. MAIZE HARVEST PRICE (Rs per Quintal) (602 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (398.0 ha)
#    Estimated Income: ₹6,727,269.76
# 204. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (399 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (601.0 ha)
#    Estimated Income: ₹6,725,987.20
# 205. MAIZE HARVEST PRICE (Rs per Quintal) (686 ha) + RICE HARVEST PRICE (Rs per Quintal) (314.0 ha)
#    Estimated Income: ₹6,723,987.24
# 206. RICE HARVEST PRICE (Rs per Quintal) (315 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (685.0 ha)
#    Estimated Income: ₹6,722,351.13
# 207. MAIZE HARVEST PRICE (Rs per Quintal) (595 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (405.0 ha)
#    Estimated Income: ₹6,718,291.86
# 208. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (406 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (594.0 ha)
#    Estimated Income: ₹6,717,009.30
# 209. MAIZE HARVEST PRICE (Rs per Quintal) (679 ha) + RICE HARVEST PRICE (Rs per Quintal) (321.0 ha)
#    Estimated Income: ₹6,712,534.43
# 210. RICE HARVEST PRICE (Rs per Quintal) (322 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (678.0 ha)
#    Estimated Income: ₹6,710,898.31
# 211. MAIZE HARVEST PRICE (Rs per Quintal) (588 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (412.0 ha)
#    Estimated Income: ₹6,709,313.95
# 212. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (413 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (587.0 ha)
#    Estimated Income: ₹6,708,031.40
# 213. MAIZE HARVEST PRICE (Rs per Quintal) (672 ha) + RICE HARVEST PRICE (Rs per Quintal) (328.0 ha)
#    Estimated Income: ₹6,701,081.62
# 214. MAIZE HARVEST PRICE (Rs per Quintal) (581 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (419.0 ha)
#    Estimated Income: ₹6,700,336.05
# 215. RICE HARVEST PRICE (Rs per Quintal) (329 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (671.0 ha)
#    Estimated Income: ₹6,699,445.50
# 216. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (420 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (580.0 ha)
#    Estimated Income: ₹6,699,053.49
# 217. MAIZE HARVEST PRICE (Rs per Quintal) (574 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (426.0 ha)
#    Estimated Income: ₹6,691,358.15
# 218. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (427 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (573.0 ha)
#    Estimated Income: ₹6,690,075.59
# 219. MAIZE HARVEST PRICE (Rs per Quintal) (665 ha) + RICE HARVEST PRICE (Rs per Quintal) (335.0 ha)
#    Estimated Income: ₹6,689,628.80
# 220. RICE HARVEST PRICE (Rs per Quintal) (336 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (664.0 ha)
#    Estimated Income: ₹6,687,992.69
# 221. MAIZE HARVEST PRICE (Rs per Quintal) (567 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (433.0 ha)
#    Estimated Income: ₹6,682,380.24
# 222. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (434 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (566.0 ha)
#    Estimated Income: ₹6,681,097.69
# 223. MAIZE HARVEST PRICE (Rs per Quintal) (658 ha) + RICE HARVEST PRICE (Rs per Quintal) (342.0 ha)
#    Estimated Income: ₹6,678,175.99
# 224. RICE HARVEST PRICE (Rs per Quintal) (343 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (657.0 ha)
#    Estimated Income: ₹6,676,539.88
# 225. MAIZE HARVEST PRICE (Rs per Quintal) (560 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (440.0 ha)
#    Estimated Income: ₹6,673,402.34
# 226. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (441 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (559.0 ha)
#    Estimated Income: ₹6,672,119.78
# 227. MAIZE HARVEST PRICE (Rs per Quintal) (651 ha) + RICE HARVEST PRICE (Rs per Quintal) (349.0 ha)
#    Estimated Income: ₹6,666,723.18
# 228. RICE HARVEST PRICE (Rs per Quintal) (350 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (650.0 ha)
#    Estimated Income: ₹6,665,087.06
# 229. MAIZE HARVEST PRICE (Rs per Quintal) (553 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (447.0 ha)
#    Estimated Income: ₹6,664,424.44
# 230. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (448 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (552.0 ha)
#    Estimated Income: ₹6,663,141.88
# 231. MAIZE HARVEST PRICE (Rs per Quintal) (546 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (454.0 ha)
#    Estimated Income: ₹6,655,446.53
# 232. MAIZE HARVEST PRICE (Rs per Quintal) (644 ha) + RICE HARVEST PRICE (Rs per Quintal) (356.0 ha)
#    Estimated Income: ₹6,655,270.37
# 233. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (455 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (545.0 ha)
#    Estimated Income: ₹6,654,163.98
# 234. RICE HARVEST PRICE (Rs per Quintal) (357 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (643.0 ha)
#    Estimated Income: ₹6,653,634.25
# 235. MAIZE HARVEST PRICE (Rs per Quintal) (539 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (461.0 ha)
#    Estimated Income: ₹6,646,468.63
# 236. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (462 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (538.0 ha)
#    Estimated Income: ₹6,645,186.07
# 237. MAIZE HARVEST PRICE (Rs per Quintal) (637 ha) + RICE HARVEST PRICE (Rs per Quintal) (363.0 ha)
#    Estimated Income: ₹6,643,817.55
# 238. RICE HARVEST PRICE (Rs per Quintal) (364 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (636.0 ha)
#    Estimated Income: ₹6,642,181.44
# 239. MAIZE HARVEST PRICE (Rs per Quintal) (532 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (468.0 ha)
#    Estimated Income: ₹6,637,490.73
# 240. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (469 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (531.0 ha)
#    Estimated Income: ₹6,636,208.17
# 241. MAIZE HARVEST PRICE (Rs per Quintal) (630 ha) + RICE HARVEST PRICE (Rs per Quintal) (370.0 ha)
#    Estimated Income: ₹6,632,364.74
# 242. RICE HARVEST PRICE (Rs per Quintal) (371 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (629.0 ha)
#    Estimated Income: ₹6,630,728.62
# 243. MAIZE HARVEST PRICE (Rs per Quintal) (525 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (475.0 ha)
#    Estimated Income: ₹6,628,512.82
# 244. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (476 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (524.0 ha)
#    Estimated Income: ₹6,627,230.26
# 245. MAIZE HARVEST PRICE (Rs per Quintal) (623 ha) + RICE HARVEST PRICE (Rs per Quintal) (377.0 ha)
#    Estimated Income: ₹6,620,911.93
# 246. MAIZE HARVEST PRICE (Rs per Quintal) (518 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (482.0 ha)
#    Estimated Income: ₹6,619,534.92
# 247. RICE HARVEST PRICE (Rs per Quintal) (378 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (622.0 ha)
#    Estimated Income: ₹6,619,275.81
# 248. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (483 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (517.0 ha)
#    Estimated Income: ₹6,618,252.36
# 249. MAIZE HARVEST PRICE (Rs per Quintal) (511 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (489.0 ha)
#    Estimated Income: ₹6,610,557.02
# 250. MAIZE HARVEST PRICE (Rs per Quintal) (616 ha) + RICE HARVEST PRICE (Rs per Quintal) (384.0 ha)
#    Estimated Income: ₹6,609,459.11
# 251. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (490 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (510.0 ha)
#    Estimated Income: ₹6,609,274.46
# 252. RICE HARVEST PRICE (Rs per Quintal) (385 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (615.0 ha)
#    Estimated Income: ₹6,607,823.00
# 253. MAIZE HARVEST PRICE (Rs per Quintal) (504 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (496.0 ha)
#    Estimated Income: ₹6,601,579.11
# 254. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (497 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (503.0 ha)
#    Estimated Income: ₹6,600,296.55
# 255. MAIZE HARVEST PRICE (Rs per Quintal) (609 ha) + RICE HARVEST PRICE (Rs per Quintal) (391.0 ha)
#    Estimated Income: ₹6,598,006.30
# 256. RICE HARVEST PRICE (Rs per Quintal) (392 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (608.0 ha)
#    Estimated Income: ₹6,596,370.18
# 257. MAIZE HARVEST PRICE (Rs per Quintal) (497 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (503.0 ha)
#    Estimated Income: ₹6,592,601.21
# 258. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (504 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (496.0 ha)
#    Estimated Income: ₹6,591,318.65
# 259. MAIZE HARVEST PRICE (Rs per Quintal) (602 ha) + RICE HARVEST PRICE (Rs per Quintal) (398.0 ha)
#    Estimated Income: ₹6,586,553.49
# 260. RICE HARVEST PRICE (Rs per Quintal) (399 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (601.0 ha)
#    Estimated Income: ₹6,584,917.37
# 261. MAIZE HARVEST PRICE (Rs per Quintal) (490 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (510.0 ha)
#    Estimated Income: ₹6,583,623.30
# 262. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (511 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (489.0 ha)
#    Estimated Income: ₹6,582,340.75
# 263. MAIZE HARVEST PRICE (Rs per Quintal) (595 ha) + RICE HARVEST PRICE (Rs per Quintal) (405.0 ha)
#    Estimated Income: ₹6,575,100.68
# 264. MAIZE HARVEST PRICE (Rs per Quintal) (483 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (517.0 ha)
#    Estimated Income: ₹6,574,645.40
# 265. RICE HARVEST PRICE (Rs per Quintal) (406 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (594.0 ha)
#    Estimated Income: ₹6,573,464.56
# 266. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (518 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (482.0 ha)
#    Estimated Income: ₹6,573,362.84
# 267. MAIZE HARVEST PRICE (Rs per Quintal) (476 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (524.0 ha)
#    Estimated Income: ₹6,565,667.50
# 268. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (525 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (475.0 ha)
#    Estimated Income: ₹6,564,384.94
# 269. MAIZE HARVEST PRICE (Rs per Quintal) (588 ha) + RICE HARVEST PRICE (Rs per Quintal) (412.0 ha)
#    Estimated Income: ₹6,563,647.86
# 270. RICE HARVEST PRICE (Rs per Quintal) (413 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (587.0 ha)
#    Estimated Income: ₹6,562,011.75
# 271. MAIZE HARVEST PRICE (Rs per Quintal) (469 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (531.0 ha)
#    Estimated Income: ₹6,556,689.59
# 272. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (532 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (468.0 ha)
#    Estimated Income: ₹6,555,407.04
# 273. MAIZE HARVEST PRICE (Rs per Quintal) (581 ha) + RICE HARVEST PRICE (Rs per Quintal) (419.0 ha)
#    Estimated Income: ₹6,552,195.05
# 274. RICE HARVEST PRICE (Rs per Quintal) (420 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (580.0 ha)
#    Estimated Income: ₹6,550,558.93
# 275. MAIZE HARVEST PRICE (Rs per Quintal) (462 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (538.0 ha)
#    Estimated Income: ₹6,547,711.69
# 276. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (539 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (461.0 ha)
#    Estimated Income: ₹6,546,429.13
# 277. MAIZE HARVEST PRICE (Rs per Quintal) (574 ha) + RICE HARVEST PRICE (Rs per Quintal) (426.0 ha)
#    Estimated Income: ₹6,540,742.24
# 278. RICE HARVEST PRICE (Rs per Quintal) (427 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (573.0 ha)
#    Estimated Income: ₹6,539,106.12
# 279. MAIZE HARVEST PRICE (Rs per Quintal) (455 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (545.0 ha)
#    Estimated Income: ₹6,538,733.79
# 280. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (546 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (454.0 ha)
#    Estimated Income: ₹6,537,451.23
# 281. MAIZE HARVEST PRICE (Rs per Quintal) (448 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (552.0 ha)
#    Estimated Income: ₹6,529,755.88
# 282. MAIZE HARVEST PRICE (Rs per Quintal) (567 ha) + RICE HARVEST PRICE (Rs per Quintal) (433.0 ha)
#    Estimated Income: ₹6,529,289.42
# 283. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (553 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (447.0 ha)
#    Estimated Income: ₹6,528,473.33
# 284. RICE HARVEST PRICE (Rs per Quintal) (434 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (566.0 ha)
#    Estimated Income: ₹6,527,653.31
# 285. MAIZE HARVEST PRICE (Rs per Quintal) (441 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (559.0 ha)
#    Estimated Income: ₹6,520,777.98
# 286. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (560 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (440.0 ha)
#    Estimated Income: ₹6,519,495.42
# 287. MAIZE HARVEST PRICE (Rs per Quintal) (560 ha) + RICE HARVEST PRICE (Rs per Quintal) (440.0 ha)
#    Estimated Income: ₹6,517,836.61
# 288. RICE HARVEST PRICE (Rs per Quintal) (441 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (559.0 ha)
#    Estimated Income: ₹6,516,200.49
# 289. MAIZE HARVEST PRICE (Rs per Quintal) (434 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (566.0 ha)
#    Estimated Income: ₹6,511,800.08
# 290. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (567 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (433.0 ha)
#    Estimated Income: ₹6,510,517.52
# 291. MAIZE HARVEST PRICE (Rs per Quintal) (553 ha) + RICE HARVEST PRICE (Rs per Quintal) (447.0 ha)
#    Estimated Income: ₹6,506,383.80
# 292. RICE HARVEST PRICE (Rs per Quintal) (448 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (552.0 ha)
#    Estimated Income: ₹6,504,747.68
# 293. MAIZE HARVEST PRICE (Rs per Quintal) (427 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (573.0 ha)
#    Estimated Income: ₹6,502,822.17
# 294. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (574 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (426.0 ha)
#    Estimated Income: ₹6,501,539.62
# 295. MAIZE HARVEST PRICE (Rs per Quintal) (546 ha) + RICE HARVEST PRICE (Rs per Quintal) (454.0 ha)
#    Estimated Income: ₹6,494,930.98
# 296. MAIZE HARVEST PRICE (Rs per Quintal) (420 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (580.0 ha)
#    Estimated Income: ₹6,493,844.27
# 297. RICE HARVEST PRICE (Rs per Quintal) (455 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (545.0 ha)
#    Estimated Income: ₹6,493,294.87
# 298. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (581 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (419.0 ha)
#    Estimated Income: ₹6,492,561.71
# 299. MAIZE HARVEST PRICE (Rs per Quintal) (413 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (587.0 ha)
#    Estimated Income: ₹6,484,866.37
# 300. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (588 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (412.0 ha)
#    Estimated Income: ₹6,483,583.81
# 301. MAIZE HARVEST PRICE (Rs per Quintal) (539 ha) + RICE HARVEST PRICE (Rs per Quintal) (461.0 ha)
#    Estimated Income: ₹6,483,478.17
# 302. RICE HARVEST PRICE (Rs per Quintal) (462 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (538.0 ha)
#    Estimated Income: ₹6,481,842.06
# 303. MAIZE HARVEST PRICE (Rs per Quintal) (406 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (594.0 ha)
#    Estimated Income: ₹6,475,888.46
# 304. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (595 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (405.0 ha)
#    Estimated Income: ₹6,474,605.90
# 305. MAIZE HARVEST PRICE (Rs per Quintal) (532 ha) + RICE HARVEST PRICE (Rs per Quintal) (468.0 ha)
#    Estimated Income: ₹6,472,025.36
# 306. RICE HARVEST PRICE (Rs per Quintal) (469 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (531.0 ha)
#    Estimated Income: ₹6,470,389.24
# 307. MAIZE HARVEST PRICE (Rs per Quintal) (399 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (601.0 ha)
#    Estimated Income: ₹6,466,910.56
# 308. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (602 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (398.0 ha)
#    Estimated Income: ₹6,465,628.00
# 309. MAIZE HARVEST PRICE (Rs per Quintal) (525 ha) + RICE HARVEST PRICE (Rs per Quintal) (475.0 ha)
#    Estimated Income: ₹6,460,572.55
# 310. RICE HARVEST PRICE (Rs per Quintal) (476 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (524.0 ha)
#    Estimated Income: ₹6,458,936.43
# 311. MAIZE HARVEST PRICE (Rs per Quintal) (392 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (608.0 ha)
#    Estimated Income: ₹6,457,932.66
# 312. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (609 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (391.0 ha)
#    Estimated Income: ₹6,456,650.10
# 313. MAIZE HARVEST PRICE (Rs per Quintal) (518 ha) + RICE HARVEST PRICE (Rs per Quintal) (482.0 ha)
#    Estimated Income: ₹6,449,119.73
# 314. MAIZE HARVEST PRICE (Rs per Quintal) (385 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (615.0 ha)
#    Estimated Income: ₹6,448,954.75
# 315. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (616 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (384.0 ha)
#    Estimated Income: ₹6,447,672.19
# 316. RICE HARVEST PRICE (Rs per Quintal) (483 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (517.0 ha)
#    Estimated Income: ₹6,447,483.62
# 317. MAIZE HARVEST PRICE (Rs per Quintal) (378 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (622.0 ha)
#    Estimated Income: ₹6,439,976.85
# 318. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (623 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (377.0 ha)
#    Estimated Income: ₹6,438,694.29
# 319. MAIZE HARVEST PRICE (Rs per Quintal) (511 ha) + RICE HARVEST PRICE (Rs per Quintal) (489.0 ha)
#    Estimated Income: ₹6,437,666.92
# 320. RICE HARVEST PRICE (Rs per Quintal) (490 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (510.0 ha)
#    Estimated Income: ₹6,436,030.80
# 321. MAIZE HARVEST PRICE (Rs per Quintal) (371 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (629.0 ha)
#    Estimated Income: ₹6,430,998.94
# 322. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (630 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (370.0 ha)
#    Estimated Income: ₹6,429,716.39
# 323. MAIZE HARVEST PRICE (Rs per Quintal) (504 ha) + RICE HARVEST PRICE (Rs per Quintal) (496.0 ha)
#    Estimated Income: ₹6,426,214.11
# 324. RICE HARVEST PRICE (Rs per Quintal) (497 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (503.0 ha)
#    Estimated Income: ₹6,424,577.99
# 325. MAIZE HARVEST PRICE (Rs per Quintal) (364 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (636.0 ha)
#    Estimated Income: ₹6,422,021.04
# 326. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (637 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (363.0 ha)
#    Estimated Income: ₹6,420,738.48
# 327. MAIZE HARVEST PRICE (Rs per Quintal) (497 ha) + RICE HARVEST PRICE (Rs per Quintal) (503.0 ha)
#    Estimated Income: ₹6,414,761.29
# 328. RICE HARVEST PRICE (Rs per Quintal) (504 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (496.0 ha)
#    Estimated Income: ₹6,413,125.18
# 329. MAIZE HARVEST PRICE (Rs per Quintal) (357 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (643.0 ha)
#    Estimated Income: ₹6,413,043.14
# 330. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (644 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (356.0 ha)
#    Estimated Income: ₹6,411,760.58
# 331. MAIZE HARVEST PRICE (Rs per Quintal) (350 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (650.0 ha)
#    Estimated Income: ₹6,404,065.23
# 332. MAIZE HARVEST PRICE (Rs per Quintal) (490 ha) + RICE HARVEST PRICE (Rs per Quintal) (510.0 ha)
#    Estimated Income: ₹6,403,308.48
# 333. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (651 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (349.0 ha)
#    Estimated Income: ₹6,402,782.68
# 334. RICE HARVEST PRICE (Rs per Quintal) (511 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (489.0 ha)
#    Estimated Income: ₹6,401,672.37
# 335. MAIZE HARVEST PRICE (Rs per Quintal) (343 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (657.0 ha)
#    Estimated Income: ₹6,395,087.33
# 336. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (658 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (342.0 ha)
#    Estimated Income: ₹6,393,804.77
# 337. MAIZE HARVEST PRICE (Rs per Quintal) (483 ha) + RICE HARVEST PRICE (Rs per Quintal) (517.0 ha)
#    Estimated Income: ₹6,391,855.67
# 338. RICE HARVEST PRICE (Rs per Quintal) (518 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (482.0 ha)
#    Estimated Income: ₹6,390,219.55
# 339. MAIZE HARVEST PRICE (Rs per Quintal) (336 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (664.0 ha)
#    Estimated Income: ₹6,386,109.43
# 340. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (665 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (335.0 ha)
#    Estimated Income: ₹6,384,826.87
# 341. MAIZE HARVEST PRICE (Rs per Quintal) (476 ha) + RICE HARVEST PRICE (Rs per Quintal) (524.0 ha)
#    Estimated Income: ₹6,380,402.86
# 342. RICE HARVEST PRICE (Rs per Quintal) (525 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (475.0 ha)
#    Estimated Income: ₹6,378,766.74
# ...
#    Estimated Income: ₹5,707,679.12
# 755. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (294 ha) + RICE HARVEST PRICE (Rs per Quintal) (706.0 ha)
#    Estimated Income: ₹5,705,557.77
# 756. RICE HARVEST PRICE (Rs per Quintal) (707 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (293.0 ha)
#    Estimated Income: ₹5,705,204.21
# 757. MAIZE HARVEST PRICE (Rs per Quintal) (63 ha) + RICE HARVEST PRICE (Rs per Quintal) (937.0 ha)
#    Estimated Income: ₹5,704,686.90
# 758. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (287 ha) + RICE HARVEST PRICE (Rs per Quintal) (713.0 ha)
#    Estimated Income: ₹5,703,082.86
# 759. RICE HARVEST PRICE (Rs per Quintal) (938 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (62.0 ha)
#    Estimated Income: ₹5,703,050.78
# 760. RICE HARVEST PRICE (Rs per Quintal) (714 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (286.0 ha)
#    Estimated Income: ₹5,702,729.30
# 761. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (280 ha) + RICE HARVEST PRICE (Rs per Quintal) (720.0 ha)
#    Estimated Income: ₹5,700,607.95
# 762. RICE HARVEST PRICE (Rs per Quintal) (721 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (279.0 ha)
#    Estimated Income: ₹5,700,254.39
# 763. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (273 ha) + RICE HARVEST PRICE (Rs per Quintal) (727.0 ha)
#    Estimated Income: ₹5,698,133.04
# 764. RICE HARVEST PRICE (Rs per Quintal) (728 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (272.0 ha)
#    Estimated Income: ₹5,697,779.49
# 765. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (266 ha) + RICE HARVEST PRICE (Rs per Quintal) (734.0 ha)
#    Estimated Income: ₹5,695,658.13
# 766. RICE HARVEST PRICE (Rs per Quintal) (735 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (265.0 ha)
#    Estimated Income: ₹5,695,304.58
# 767. MAIZE HARVEST PRICE (Rs per Quintal) (56 ha) + RICE HARVEST PRICE (Rs per Quintal) (944.0 ha)
#    Estimated Income: ₹5,693,234.08
# 768. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (259 ha) + RICE HARVEST PRICE (Rs per Quintal) (741.0 ha)
#    Estimated Income: ₹5,693,183.23
# 769. RICE HARVEST PRICE (Rs per Quintal) (742 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (258.0 ha)
#    Estimated Income: ₹5,692,829.67
# 770. RICE HARVEST PRICE (Rs per Quintal) (945 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (55.0 ha)
#    Estimated Income: ₹5,691,597.97
# 771. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (252 ha) + RICE HARVEST PRICE (Rs per Quintal) (748.0 ha)
#    Estimated Income: ₹5,690,708.32
# 772. RICE HARVEST PRICE (Rs per Quintal) (749 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (251.0 ha)
#    Estimated Income: ₹5,690,354.76
# 773. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (245 ha) + RICE HARVEST PRICE (Rs per Quintal) (755.0 ha)
#    Estimated Income: ₹5,688,233.41
# 774. RICE HARVEST PRICE (Rs per Quintal) (756 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (244.0 ha)
#    Estimated Income: ₹5,687,879.85
# 775. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (238 ha) + RICE HARVEST PRICE (Rs per Quintal) (762.0 ha)
#    Estimated Income: ₹5,685,758.50
# 776. RICE HARVEST PRICE (Rs per Quintal) (763 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (237.0 ha)
#    Estimated Income: ₹5,685,404.94
# 777. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (231 ha) + RICE HARVEST PRICE (Rs per Quintal) (769.0 ha)
#    Estimated Income: ₹5,683,283.59
# 778. RICE HARVEST PRICE (Rs per Quintal) (770 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (230.0 ha)
#    Estimated Income: ₹5,682,930.03
# 779. MAIZE HARVEST PRICE (Rs per Quintal) (49 ha) + RICE HARVEST PRICE (Rs per Quintal) (951.0 ha)
#    Estimated Income: ₹5,681,781.27
# 780. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (224 ha) + RICE HARVEST PRICE (Rs per Quintal) (776.0 ha)
#    Estimated Income: ₹5,680,808.68
# 781. RICE HARVEST PRICE (Rs per Quintal) (777 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (223.0 ha)
#    Estimated Income: ₹5,680,455.12
# 782. RICE HARVEST PRICE (Rs per Quintal) (952 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (48.0 ha)
#    Estimated Income: ₹5,680,145.15
# 783. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (217 ha) + RICE HARVEST PRICE (Rs per Quintal) (783.0 ha)
#    Estimated Income: ₹5,678,333.77
# 784. RICE HARVEST PRICE (Rs per Quintal) (784 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (216.0 ha)
#    Estimated Income: ₹5,677,980.21
# 785. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (210 ha) + RICE HARVEST PRICE (Rs per Quintal) (790.0 ha)
#    Estimated Income: ₹5,675,858.86
# 786. RICE HARVEST PRICE (Rs per Quintal) (791 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (209.0 ha)
#    Estimated Income: ₹5,675,505.30
# 787. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (203 ha) + RICE HARVEST PRICE (Rs per Quintal) (797.0 ha)
#    Estimated Income: ₹5,673,383.95
# 788. RICE HARVEST PRICE (Rs per Quintal) (798 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (202.0 ha)
#    Estimated Income: ₹5,673,030.39
# 789. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (196 ha) + RICE HARVEST PRICE (Rs per Quintal) (804.0 ha)
#    Estimated Income: ₹5,670,909.04
# 790. RICE HARVEST PRICE (Rs per Quintal) (805 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (195.0 ha)
#    Estimated Income: ₹5,670,555.48
# 791. MAIZE HARVEST PRICE (Rs per Quintal) (42 ha) + RICE HARVEST PRICE (Rs per Quintal) (958.0 ha)
#    Estimated Income: ₹5,670,328.46
# 792. RICE HARVEST PRICE (Rs per Quintal) (959 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (41.0 ha)
#    Estimated Income: ₹5,668,692.34
# 793. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (189 ha) + RICE HARVEST PRICE (Rs per Quintal) (811.0 ha)
#    Estimated Income: ₹5,668,434.13
# 794. RICE HARVEST PRICE (Rs per Quintal) (812 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹5,668,080.57
# 795. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (182 ha) + RICE HARVEST PRICE (Rs per Quintal) (818.0 ha)
#    Estimated Income: ₹5,665,959.22
# 796. RICE HARVEST PRICE (Rs per Quintal) (819 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (181.0 ha)
#    Estimated Income: ₹5,665,605.66
# 797. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (175 ha) + RICE HARVEST PRICE (Rs per Quintal) (825.0 ha)
#    Estimated Income: ₹5,663,484.31
# 798. RICE HARVEST PRICE (Rs per Quintal) (826 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (174.0 ha)
#    Estimated Income: ₹5,663,130.75
# 799. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (168 ha) + RICE HARVEST PRICE (Rs per Quintal) (832.0 ha)
#    Estimated Income: ₹5,661,009.40
# 800. RICE HARVEST PRICE (Rs per Quintal) (833 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (167.0 ha)
#    Estimated Income: ₹5,660,655.85
# 801. MAIZE HARVEST PRICE (Rs per Quintal) (35 ha) + RICE HARVEST PRICE (Rs per Quintal) (965.0 ha)
#    Estimated Income: ₹5,658,875.64
# 802. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (161 ha) + RICE HARVEST PRICE (Rs per Quintal) (839.0 ha)
#    Estimated Income: ₹5,658,534.49
# 803. RICE HARVEST PRICE (Rs per Quintal) (840 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (160.0 ha)
#    Estimated Income: ₹5,658,180.94
# 804. RICE HARVEST PRICE (Rs per Quintal) (966 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (34.0 ha)
#    Estimated Income: ₹5,657,239.53
# 805. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (154 ha) + RICE HARVEST PRICE (Rs per Quintal) (846.0 ha)
#    Estimated Income: ₹5,656,059.59
# 806. RICE HARVEST PRICE (Rs per Quintal) (847 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (153.0 ha)
#    Estimated Income: ₹5,655,706.03
# 807. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (147 ha) + RICE HARVEST PRICE (Rs per Quintal) (853.0 ha)
#    Estimated Income: ₹5,653,584.68
# 808. RICE HARVEST PRICE (Rs per Quintal) (854 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (146.0 ha)
#    Estimated Income: ₹5,653,231.12
# 809. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (140 ha) + RICE HARVEST PRICE (Rs per Quintal) (860.0 ha)
#    Estimated Income: ₹5,651,109.77
# 810. RICE HARVEST PRICE (Rs per Quintal) (861 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (139.0 ha)
#    Estimated Income: ₹5,650,756.21
# 811. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (133 ha) + RICE HARVEST PRICE (Rs per Quintal) (867.0 ha)
#    Estimated Income: ₹5,648,634.86
# 812. RICE HARVEST PRICE (Rs per Quintal) (868 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (132.0 ha)
#    Estimated Income: ₹5,648,281.30
# 813. MAIZE HARVEST PRICE (Rs per Quintal) (28 ha) + RICE HARVEST PRICE (Rs per Quintal) (972.0 ha)
#    Estimated Income: ₹5,647,422.83
# 814. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (126 ha) + RICE HARVEST PRICE (Rs per Quintal) (874.0 ha)
#    Estimated Income: ₹5,646,159.95
# 815. RICE HARVEST PRICE (Rs per Quintal) (875 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (125.0 ha)
#    Estimated Income: ₹5,645,806.39
# 816. RICE HARVEST PRICE (Rs per Quintal) (973 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (27.0 ha)
#    Estimated Income: ₹5,645,786.72
# 817. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (119 ha) + RICE HARVEST PRICE (Rs per Quintal) (881.0 ha)
#    Estimated Income: ₹5,643,685.04
# 818. RICE HARVEST PRICE (Rs per Quintal) (882 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (118.0 ha)
#    Estimated Income: ₹5,643,331.48
# 819. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (112 ha) + RICE HARVEST PRICE (Rs per Quintal) (888.0 ha)
#    Estimated Income: ₹5,641,210.13
# 820. RICE HARVEST PRICE (Rs per Quintal) (889 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (111.0 ha)
#    Estimated Income: ₹5,640,856.57
# 821. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (105 ha) + RICE HARVEST PRICE (Rs per Quintal) (895.0 ha)
#    Estimated Income: ₹5,638,735.22
# 822. RICE HARVEST PRICE (Rs per Quintal) (896 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹5,638,381.66
# 823. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (98 ha) + RICE HARVEST PRICE (Rs per Quintal) (902.0 ha)
#    Estimated Income: ₹5,636,260.31
# 824. MAIZE HARVEST PRICE (Rs per Quintal) (21 ha) + RICE HARVEST PRICE (Rs per Quintal) (979.0 ha)
#    Estimated Income: ₹5,635,970.02
# 825. RICE HARVEST PRICE (Rs per Quintal) (903 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (97.0 ha)
#    Estimated Income: ₹5,635,906.75
# 826. RICE HARVEST PRICE (Rs per Quintal) (980 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹5,634,333.90
# 827. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (91 ha) + RICE HARVEST PRICE (Rs per Quintal) (909.0 ha)
#    Estimated Income: ₹5,633,785.40
# 828. RICE HARVEST PRICE (Rs per Quintal) (910 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (90.0 ha)
#    Estimated Income: ₹5,633,431.84
# 829. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (84 ha) + RICE HARVEST PRICE (Rs per Quintal) (916.0 ha)
#    Estimated Income: ₹5,631,310.49
# 830. RICE HARVEST PRICE (Rs per Quintal) (917 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (83.0 ha)
#    Estimated Income: ₹5,630,956.93
# 831. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (77 ha) + RICE HARVEST PRICE (Rs per Quintal) (923.0 ha)
#    Estimated Income: ₹5,628,835.58
# 832. RICE HARVEST PRICE (Rs per Quintal) (924 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (76.0 ha)
#    Estimated Income: ₹5,628,482.02
# 833. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (70 ha) + RICE HARVEST PRICE (Rs per Quintal) (930.0 ha)
#    Estimated Income: ₹5,626,360.67
# 834. RICE HARVEST PRICE (Rs per Quintal) (931 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (69.0 ha)
#    Estimated Income: ₹5,626,007.11
# 835. MAIZE HARVEST PRICE (Rs per Quintal) (14 ha) + RICE HARVEST PRICE (Rs per Quintal) (986.0 ha)
#    Estimated Income: ₹5,624,517.21
# 836. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (63 ha) + RICE HARVEST PRICE (Rs per Quintal) (937.0 ha)
#    Estimated Income: ₹5,623,885.76
# 837. RICE HARVEST PRICE (Rs per Quintal) (938 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (62.0 ha)
#    Estimated Income: ₹5,623,532.21
# 838. RICE HARVEST PRICE (Rs per Quintal) (987 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (13.0 ha)
#    Estimated Income: ₹5,622,881.09
# 839. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (56 ha) + RICE HARVEST PRICE (Rs per Quintal) (944.0 ha)
#    Estimated Income: ₹5,621,410.85
# 840. RICE HARVEST PRICE (Rs per Quintal) (945 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (55.0 ha)
#    Estimated Income: ₹5,621,057.30
# 841. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (49 ha) + RICE HARVEST PRICE (Rs per Quintal) (951.0 ha)
#    Estimated Income: ₹5,618,935.94
# 842. RICE HARVEST PRICE (Rs per Quintal) (952 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (48.0 ha)
#    Estimated Income: ₹5,618,582.39
# 843. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (42 ha) + RICE HARVEST PRICE (Rs per Quintal) (958.0 ha)
#    Estimated Income: ₹5,616,461.04
# 844. RICE HARVEST PRICE (Rs per Quintal) (959 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (41.0 ha)
#    Estimated Income: ₹5,616,107.48
# 845. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (35 ha) + RICE HARVEST PRICE (Rs per Quintal) (965.0 ha)
#    Estimated Income: ₹5,613,986.13
# 846. RICE HARVEST PRICE (Rs per Quintal) (966 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (34.0 ha)
#    Estimated Income: ₹5,613,632.57
# 847. MAIZE HARVEST PRICE (Rs per Quintal) (7 ha) + RICE HARVEST PRICE (Rs per Quintal) (993.0 ha)
#    Estimated Income: ₹5,613,064.39
# 848. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (28 ha) + RICE HARVEST PRICE (Rs per Quintal) (972.0 ha)
#    Estimated Income: ₹5,611,511.22
# 849. RICE HARVEST PRICE (Rs per Quintal) (994 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (6.0 ha)
#    Estimated Income: ₹5,611,428.28
# 850. RICE HARVEST PRICE (Rs per Quintal) (973 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (27.0 ha)
#    Estimated Income: ₹5,611,157.66
# 851. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (21 ha) + RICE HARVEST PRICE (Rs per Quintal) (979.0 ha)
#    Estimated Income: ₹5,609,036.31
# 852. RICE HARVEST PRICE (Rs per Quintal) (980 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹5,608,682.75
# 853. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (14 ha) + RICE HARVEST PRICE (Rs per Quintal) (986.0 ha)
#    Estimated Income: ₹5,606,561.40
# 854. RICE HARVEST PRICE (Rs per Quintal) (987 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (13.0 ha)
#    Estimated Income: ₹5,606,207.84
# 855. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (7 ha) + RICE HARVEST PRICE (Rs per Quintal) (993.0 ha)
#    Estimated Income: ₹5,604,086.49
# 856. RICE HARVEST PRICE (Rs per Quintal) (994 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (6.0 ha)
#    Estimated Income: ₹5,603,732.93
# 857. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + RICE HARVEST PRICE (Rs per Quintal) (1000.0 ha)
#    Estimated Income: ₹5,601,611.58
# 858. MAIZE HARVEST PRICE (Rs per Quintal) (0 ha) + RICE HARVEST PRICE (Rs per Quintal) (1000.0 ha)
#    Estimated Income: ₹5,601,611.58
#
# Top 5 Crop Combinations for Maximum Income:
# 1. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (1000.0 ha)
#    Estimated Income: ₹7,237,727.71
# 2. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (1000.0 ha)
#    Estimated Income: ₹7,237,727.71
# 3. MAIZE HARVEST PRICE (Rs per Quintal) (994 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (6.0 ha)
#    Estimated Income: ₹7,230,032.36
# 4. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (7 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (993.0 ha)
#    Estimated Income: ₹7,228,749.80
# 5. MAIZE HARVEST PRICE (Rs per Quintal) (994 ha) + RICE HARVEST PRICE (Rs per Quintal) (6.0 ha)
#    Estimated Income: ₹7,227,911.01
#
# Optimal Crop Combination(s) for Maximum Revenue:
# 1. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (1000.0 ha)
#    Maximum Estimated Income: ₹7,237,727.71
#    Soil Suitability: RICE (100.00%), MAIZE (0.00%)
# 2. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (1000.0 ha)
#    Maximum Estimated Income: ₹7,237,727.71
#    Soil Suitability: COTTON KAPAS (0.00%), MAIZE (0.00%)
# c:\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import itertools

# Load datasets
crop_df = pd.read_csv('data.csv')
yield_df = pd.read_csv('commodity_yield.csv')
icrisat_df = pd.read_csv('ICRISAT-District Level Data.csv')
price_df = pd.read_csv('pricesdataset.csv')

def preprocess_data():
    """Extract crop price data from ICRISAT dataset."""
    price_columns = [col for col in icrisat_df.columns if 'HARVEST PRICE' in col]
    crop_prices = {}
    
    for column in price_columns:
        crop_name = column.split(' HARVEST')[0].strip()
        crop_prices[crop_name] = icrisat_df[column].mean()
    
    return crop_prices, price_columns

def get_suitable_crops(n, p, k, temp, humidity, ph, rainfall):
    """Find suitable crops based on soil parameters using KNN."""
    X = crop_df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
    y = crop_df['label']
    
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X, y)
    
    farm_conditions = [n, p, k, temp, humidity, ph, rainfall]
    probabilities = knn.predict_proba([farm_conditions])[0]
    crops = knn.classes_
    
    # Return all crops with their suitability probability
    return sorted(zip(crops, probabilities), key=lambda x: x[1], reverse=True)

def match_crop_data(suitable_crops, yield_df, price_columns, crop_prices):
    """Match suitable crops with yield and price data."""
    crop_data = {}
    
    for crop_name, probability in suitable_crops:
        # Convert to uppercase for matching with ICRISAT columns
        crop_upper = crop_name.upper()
        
        # Find matching price column
        matching_columns = [col for col in price_columns if crop_upper in col]
        if not matching_columns:
            continue
            
        # Get yield data
        yield_values = yield_df[yield_df['Commodity'].str.lower() == crop_name.lower()]['Yield_Quintals_Per_Hectare'].values
        if len(yield_values) == 0:
            continue
            
        # Get the crop name from the price column
        icrisat_crop_name = matching_columns[0].split(' HARVEST')[0].strip()
        
        crop_data[icrisat_crop_name] = {
            'yield': yield_values[0],
            'price': crop_prices[icrisat_crop_name],
            'probability': probability
        }
    
    return crop_data

def generate_crop_combinations(crop_data, total_area=100, step_size=10):
    """Generate all crop combinations with variable area allocations."""
    combinations = []
    
    # Get all pairs of crops
    crop_pairs = list(itertools.permutations(crop_data.keys(), 2))
    
    # Try different area allocations with specified step size
    for area1 in range(0, int(total_area + 1), step_size):
        area2 = total_area - area1
        
        for crop1, crop2 in crop_pairs:
            # Calculate revenue
            revenue = (area1 * crop_data[crop1]['yield'] * crop_data[crop1]['price']) + \
                     (area2 * crop_data[crop2]['yield'] * crop_data[crop2]['price'])
            
            combinations.append({
                'crop1': crop1,
                'area1': area1,
                'crop2': crop2,
                'area2': area2,
                'revenue': revenue,
                'crop1_prob': crop_data[crop1]['probability'],
                'crop2_prob': crop_data[crop2]['probability']
            })
    
    # Sort by revenue in descending order
    combinations.sort(key=lambda x: x['revenue'], reverse=True)
    return combinations

def refine_recommendations(combinations, soil_suitability_weight=0.3):
    """Refine recommendations by balancing revenue with soil suitability."""
    refined_combinations = []
    
    for combo in combinations:
        # Calculate soil suitability score (average of both crops' probabilities)
        soil_score = (combo['crop1_prob'] + combo['crop2_prob']) / 2
        
        # Create a combined score that balances revenue and soil suitability
        # We normalize revenue by the maximum revenue in the combinations
        max_revenue = combinations[0]['revenue']
        
        # Normalized revenue (0-1 scale)
        norm_revenue = combo['revenue'] / max_revenue
        
        # Combined score - weighted average of revenue and soil suitability
        combined_score = (1 - soil_suitability_weight) * norm_revenue + soil_suitability_weight * soil_score
        
        combo['combined_score'] = combined_score
        refined_combinations.append(combo)
    
    # Sort by combined score
    refined_combinations.sort(key=lambda x: x['combined_score'], reverse=True)
    return refined_combinations

def display_crop_recommendations(ordered_by='revenue'):
    """Main function to recommend crops based on soil and area."""
    # Input farm conditions
    print("Enter soil and climate parameters:")
    n = float(input("Enter Nitrogen (N) content (kg/ha): "))
    p = float(input("Enter Phosphorus (P) content (kg/ha): "))
    k = float(input("Enter Potassium (K) content (kg/ha): "))
    temp = float(input("Enter Temperature (°C): "))
    humidity = float(input("Enter Humidity (%): "))
    ph = float(input("Enter pH: "))
    rainfall = float(input("Enter Rainfall (mm): "))
    
    total_area = float(input("Enter total available area (hectares): "))
    step_size = int(input("Enter step size for area allocation (10 recommended): "))
    
    # Preprocess data
    crop_prices, price_columns = preprocess_data()
    
    # Get suitable crops based on soil parameters
    suitable_crops = get_suitable_crops(n, p, k, temp, humidity, ph, rainfall)
    
    print("\nRecommended Crops (In Order of Suitability):")
    for i, (crop, prob) in enumerate(suitable_crops[:10], 1):
        print(f"{i}. {crop.capitalize()}")
    
    # Match suitable crops with yield and price data
    crop_data = match_crop_data(suitable_crops, yield_df, price_columns, crop_prices)
    
    # Check if we have enough crop data
    if len(crop_data) < 2:
        print("Insufficient crop data. Please check the datasets or adjust soil parameters.")
        return
    
    # Generate crop combinations with varying area allocations
    combinations = generate_crop_combinations(crop_data, total_area, step_size)
    
    # Refine recommendations if ordered by combined score
    if ordered_by == 'combined':
        combinations = refine_recommendations(combinations)
    
    # Display all tested combinations
    print("\nAll Tested Crop Combinations:")
    for i, combo in enumerate(combinations, 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Estimated Income: ₹{combo['revenue']:,.2f}")
    
    # Display the top 5 combinations
    print("\nTop 5 Crop Combinations for Maximum Income:")
    for i, combo in enumerate(combinations[:5], 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Estimated Income: ₹{combo['revenue']:,.2f}")
    
    # Store all revenues
    revenues = [combo['revenue'] for combo in combinations]
    
    # Find the maximum revenue
    max_revenue = max(revenues) if revenues else 0
    
    # Find the combination(s) that give the maximum revenue
    max_combinations = [combo for combo in combinations if combo['revenue'] == max_revenue]
    
    # Display the maximum revenue combination
    print("\nOptimal Crop Combination for Maximum Revenue:")
    for i, combo in enumerate(max_combinations, 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Maximum Estimated Income: ₹{combo['revenue']:,.2f}")
        print(f"   Soil Suitability: {combo['crop1']} ({combo['crop1_prob']:.2%}), {combo['crop2']} ({combo['crop2_prob']:.2%})")

def main():
    """Main entry point with option to choose recommendation criteria."""
    print("Crop Recommendation System")
    print("==========================")
    print("1. Recommend crops based on maximum revenue")
    print("2. Recommend crops balancing revenue and soil suitability")
    
    choice = input("Enter your choice (1 or 2): ")
    
    if choice == '2':
        display_crop_recommendations('combined')
    else:
        display_crop_recommendations('revenue')

if __name__ == "__main__":
    main()
# Out:
# Crop Recommendation System
# ==========================
# 1. Recommend crops based on maximum revenue
# 2. Recommend crops balancing revenue and soil suitability
# Enter soil and climate parameters:
#
# Recommended Crops (In Order of Suitability):
# 1. Coconut)
# 2. Jute)
# 3. Pigeonpeas)
# 4. Apple)
# 5. Banana)
# 6. Blackgram)
# 7. Chickpea)
# 8. Coffee)
# 9. Cotton)
# 10. Grapes)
#
# All Tested Crop Combinations:
# 1. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,447,545.54
# 2. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,447,545.54
# 3. MAIZE HARVEST PRICE (Rs per Quintal) (200 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Estimated Income: ₹1,447,545.54
# 4. MAIZE HARVEST PRICE (Rs per Quintal) (200 ha) + RICE HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Estimated Income: ₹1,447,545.54
# 5. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (4 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (196.0 ha)
#    Estimated Income: ₹1,442,415.31
# 6. MAIZE HARVEST PRICE (Rs per Quintal) (196 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (4.0 ha)
#    Estimated Income: ₹1,442,415.31
# 7. RICE HARVEST PRICE (Rs per Quintal) (4 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (196.0 ha)
#    Estimated Income: ₹1,441,001.08
# 8. MAIZE HARVEST PRICE (Rs per Quintal) (196 ha) + RICE HARVEST PRICE (Rs per Quintal) (4.0 ha)
#    Estimated Income: ₹1,441,001.08
# 9. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (8 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (192.0 ha)
#    Estimated Income: ₹1,437,285.08
# 10. MAIZE HARVEST PRICE (Rs per Quintal) (192 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,437,285.08
# 11. RICE HARVEST PRICE (Rs per Quintal) (8 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (192.0 ha)
#    Estimated Income: ₹1,434,456.61
# 12. MAIZE HARVEST PRICE (Rs per Quintal) (192 ha) + RICE HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,434,456.61
# 13. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (12 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,432,154.85
# 14. MAIZE HARVEST PRICE (Rs per Quintal) (188 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (12.0 ha)
#    Estimated Income: ₹1,432,154.85
# 15. RICE HARVEST PRICE (Rs per Quintal) (12 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,427,912.15
# 16. MAIZE HARVEST PRICE (Rs per Quintal) (188 ha) + RICE HARVEST PRICE (Rs per Quintal) (12.0 ha)
#    Estimated Income: ₹1,427,912.15
# 17. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (16 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (184.0 ha)
#    Estimated Income: ₹1,427,024.62
# 18. MAIZE HARVEST PRICE (Rs per Quintal) (184 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (16.0 ha)
#    Estimated Income: ₹1,427,024.62
# 19. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (20 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (180.0 ha)
#    Estimated Income: ₹1,421,894.39
# 20. MAIZE HARVEST PRICE (Rs per Quintal) (180 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,421,894.39
# 21. RICE HARVEST PRICE (Rs per Quintal) (16 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (184.0 ha)
#    Estimated Income: ₹1,421,367.68
# 22. MAIZE HARVEST PRICE (Rs per Quintal) (184 ha) + RICE HARVEST PRICE (Rs per Quintal) (16.0 ha)
#    Estimated Income: ₹1,421,367.68
# 23. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (24 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,416,764.16
# 24. MAIZE HARVEST PRICE (Rs per Quintal) (176 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (24.0 ha)
#    Estimated Income: ₹1,416,764.16
# 25. RICE HARVEST PRICE (Rs per Quintal) (20 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (180.0 ha)
#    Estimated Income: ₹1,414,823.22
# 26. MAIZE HARVEST PRICE (Rs per Quintal) (180 ha) + RICE HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,414,823.22
# 27. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (28 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (172.0 ha)
#    Estimated Income: ₹1,411,633.93
# 28. MAIZE HARVEST PRICE (Rs per Quintal) (172 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (28.0 ha)
#    Estimated Income: ₹1,411,633.93
# 29. RICE HARVEST PRICE (Rs per Quintal) (24 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,408,278.75
# 30. MAIZE HARVEST PRICE (Rs per Quintal) (176 ha) + RICE HARVEST PRICE (Rs per Quintal) (24.0 ha)
#    Estimated Income: ₹1,408,278.75
# 31. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (32 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (168.0 ha)
#    Estimated Income: ₹1,406,503.70
# 32. MAIZE HARVEST PRICE (Rs per Quintal) (168 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,406,503.70
# 33. RICE HARVEST PRICE (Rs per Quintal) (28 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (172.0 ha)
#    Estimated Income: ₹1,401,734.29
# 34. MAIZE HARVEST PRICE (Rs per Quintal) (172 ha) + RICE HARVEST PRICE (Rs per Quintal) (28.0 ha)
#    Estimated Income: ₹1,401,734.29
# 35. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (36 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,401,373.47
# 36. MAIZE HARVEST PRICE (Rs per Quintal) (164 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (36.0 ha)
#    Estimated Income: ₹1,401,373.47
# 37. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (40 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (160.0 ha)
#    Estimated Income: ₹1,396,243.24
# 38. MAIZE HARVEST PRICE (Rs per Quintal) (160 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (40.0 ha)
#    Estimated Income: ₹1,396,243.24
# 39. RICE HARVEST PRICE (Rs per Quintal) (32 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (168.0 ha)
#    Estimated Income: ₹1,395,189.83
# 40. MAIZE HARVEST PRICE (Rs per Quintal) (168 ha) + RICE HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,395,189.83
# 41. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (44 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (156.0 ha)
#    Estimated Income: ₹1,391,113.00
# 42. MAIZE HARVEST PRICE (Rs per Quintal) (156 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,391,113.00
# 43. RICE HARVEST PRICE (Rs per Quintal) (36 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,388,645.36
# 44. MAIZE HARVEST PRICE (Rs per Quintal) (164 ha) + RICE HARVEST PRICE (Rs per Quintal) (36.0 ha)
#    Estimated Income: ₹1,388,645.36
# 45. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (48 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,385,982.77
# 46. MAIZE HARVEST PRICE (Rs per Quintal) (152 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (48.0 ha)
#    Estimated Income: ₹1,385,982.77
# 47. RICE HARVEST PRICE (Rs per Quintal) (40 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (160.0 ha)
#    Estimated Income: ₹1,382,100.90
# 48. MAIZE HARVEST PRICE (Rs per Quintal) (160 ha) + RICE HARVEST PRICE (Rs per Quintal) (40.0 ha)
#    Estimated Income: ₹1,382,100.90
# 49. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (52 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (148.0 ha)
#    Estimated Income: ₹1,380,852.54
# 50. MAIZE HARVEST PRICE (Rs per Quintal) (148 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (52.0 ha)
#    Estimated Income: ₹1,380,852.54
# 51. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (56 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (144.0 ha)
#    Estimated Income: ₹1,375,722.31
# 52. MAIZE HARVEST PRICE (Rs per Quintal) (144 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,375,722.31
# 53. RICE HARVEST PRICE (Rs per Quintal) (44 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (156.0 ha)
#    Estimated Income: ₹1,375,556.43
# 54. MAIZE HARVEST PRICE (Rs per Quintal) (156 ha) + RICE HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,375,556.43
# 55. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (60 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,370,592.08
# 56. MAIZE HARVEST PRICE (Rs per Quintal) (140 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (60.0 ha)
#    Estimated Income: ₹1,370,592.08
# 57. RICE HARVEST PRICE (Rs per Quintal) (48 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,369,011.97
# 58. MAIZE HARVEST PRICE (Rs per Quintal) (152 ha) + RICE HARVEST PRICE (Rs per Quintal) (48.0 ha)
#    Estimated Income: ₹1,369,011.97
# 59. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (64 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (136.0 ha)
#    Estimated Income: ₹1,365,461.85
# 60. MAIZE HARVEST PRICE (Rs per Quintal) (136 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (64.0 ha)
#    Estimated Income: ₹1,365,461.85
# 61. RICE HARVEST PRICE (Rs per Quintal) (52 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (148.0 ha)
#    Estimated Income: ₹1,362,467.50
# 62. MAIZE HARVEST PRICE (Rs per Quintal) (148 ha) + RICE HARVEST PRICE (Rs per Quintal) (52.0 ha)
#    Estimated Income: ₹1,362,467.50
# 63. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (68 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (132.0 ha)
#    Estimated Income: ₹1,360,331.62
# 64. MAIZE HARVEST PRICE (Rs per Quintal) (132 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,360,331.62
# 65. RICE HARVEST PRICE (Rs per Quintal) (56 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (144.0 ha)
#    Estimated Income: ₹1,355,923.04
# 66. MAIZE HARVEST PRICE (Rs per Quintal) (144 ha) + RICE HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,355,923.04
# 67. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (72 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,355,201.39
# 68. MAIZE HARVEST PRICE (Rs per Quintal) (128 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (72.0 ha)
#    Estimated Income: ₹1,355,201.39
# 69. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (76 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (124.0 ha)
#    Estimated Income: ₹1,350,071.16
# 70. MAIZE HARVEST PRICE (Rs per Quintal) (124 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (76.0 ha)
#    Estimated Income: ₹1,350,071.16
# 71. RICE HARVEST PRICE (Rs per Quintal) (60 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,349,378.57
# 72. MAIZE HARVEST PRICE (Rs per Quintal) (140 ha) + RICE HARVEST PRICE (Rs per Quintal) (60.0 ha)
#    Estimated Income: ₹1,349,378.57
# 73. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (80 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (120.0 ha)
#    Estimated Income: ₹1,344,940.93
# 74. MAIZE HARVEST PRICE (Rs per Quintal) (120 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,344,940.93
# 75. RICE HARVEST PRICE (Rs per Quintal) (64 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (136.0 ha)
#    Estimated Income: ₹1,342,834.11
# 76. MAIZE HARVEST PRICE (Rs per Quintal) (136 ha) + RICE HARVEST PRICE (Rs per Quintal) (64.0 ha)
#    Estimated Income: ₹1,342,834.11
# 77. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (84 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,339,810.70
# 78. MAIZE HARVEST PRICE (Rs per Quintal) (116 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (84.0 ha)
#    Estimated Income: ₹1,339,810.70
# 79. RICE HARVEST PRICE (Rs per Quintal) (68 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (132.0 ha)
#    Estimated Income: ₹1,336,289.64
# 80. MAIZE HARVEST PRICE (Rs per Quintal) (132 ha) + RICE HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,336,289.64
# 81. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (88 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (112.0 ha)
#    Estimated Income: ₹1,334,680.47
# 82. MAIZE HARVEST PRICE (Rs per Quintal) (112 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (88.0 ha)
#    Estimated Income: ₹1,334,680.47
# 83. RICE HARVEST PRICE (Rs per Quintal) (72 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,329,745.18
# 84. MAIZE HARVEST PRICE (Rs per Quintal) (128 ha) + RICE HARVEST PRICE (Rs per Quintal) (72.0 ha)
#    Estimated Income: ₹1,329,745.18
# 85. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (92 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (108.0 ha)
#    Estimated Income: ₹1,329,550.24
# 86. MAIZE HARVEST PRICE (Rs per Quintal) (108 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,329,550.24
# 87. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (96 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,324,420.01
# 88. MAIZE HARVEST PRICE (Rs per Quintal) (104 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (96.0 ha)
#    Estimated Income: ₹1,324,420.01
# 89. RICE HARVEST PRICE (Rs per Quintal) (76 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (124.0 ha)
#    Estimated Income: ₹1,323,200.72
# 90. MAIZE HARVEST PRICE (Rs per Quintal) (124 ha) + RICE HARVEST PRICE (Rs per Quintal) (76.0 ha)
#    Estimated Income: ₹1,323,200.72
# 91. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (100 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (100.0 ha)
#    Estimated Income: ₹1,319,289.78
# 92. MAIZE HARVEST PRICE (Rs per Quintal) (100 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (100.0 ha)
#    Estimated Income: ₹1,319,289.78
# 93. RICE HARVEST PRICE (Rs per Quintal) (80 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (120.0 ha)
#    Estimated Income: ₹1,316,656.25
# 94. MAIZE HARVEST PRICE (Rs per Quintal) (120 ha) + RICE HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,316,656.25
# 95. MAIZE HARVEST PRICE (Rs per Quintal) (96 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,314,159.55
# 96. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (104 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (96.0 ha)
#    Estimated Income: ₹1,314,159.55
# 97. RICE HARVEST PRICE (Rs per Quintal) (84 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,310,111.79
# 98. MAIZE HARVEST PRICE (Rs per Quintal) (116 ha) + RICE HARVEST PRICE (Rs per Quintal) (84.0 ha)
#    Estimated Income: ₹1,310,111.79
# 99. MAIZE HARVEST PRICE (Rs per Quintal) (92 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (108.0 ha)
#    Estimated Income: ₹1,309,029.32
# 100. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (108 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,309,029.32
# 101. MAIZE HARVEST PRICE (Rs per Quintal) (88 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (112.0 ha)
#    Estimated Income: ₹1,303,899.08
# 102. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (112 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (88.0 ha)
#    Estimated Income: ₹1,303,899.08
# 103. RICE HARVEST PRICE (Rs per Quintal) (88 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (112.0 ha)
#    Estimated Income: ₹1,303,567.32
# 104. MAIZE HARVEST PRICE (Rs per Quintal) (112 ha) + RICE HARVEST PRICE (Rs per Quintal) (88.0 ha)
#    Estimated Income: ₹1,303,567.32
# 105. MAIZE HARVEST PRICE (Rs per Quintal) (84 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,298,768.85
# 106. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (116 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (84.0 ha)
#    Estimated Income: ₹1,298,768.85
# 107. RICE HARVEST PRICE (Rs per Quintal) (92 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (108.0 ha)
#    Estimated Income: ₹1,297,022.86
# 108. MAIZE HARVEST PRICE (Rs per Quintal) (108 ha) + RICE HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,297,022.86
# 109. MAIZE HARVEST PRICE (Rs per Quintal) (80 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (120.0 ha)
#    Estimated Income: ₹1,293,638.62
# 110. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (120 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,293,638.62
# 111. RICE HARVEST PRICE (Rs per Quintal) (96 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,290,478.39
# 112. MAIZE HARVEST PRICE (Rs per Quintal) (104 ha) + RICE HARVEST PRICE (Rs per Quintal) (96.0 ha)
#    Estimated Income: ₹1,290,478.39
# 113. MAIZE HARVEST PRICE (Rs per Quintal) (76 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (124.0 ha)
#    Estimated Income: ₹1,288,508.39
# 114. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (124 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (76.0 ha)
#    Estimated Income: ₹1,288,508.39
# 115. MAIZE HARVEST PRICE (Rs per Quintal) (100 ha) + RICE HARVEST PRICE (Rs per Quintal) (100.0 ha)
#    Estimated Income: ₹1,283,933.93
# 116. RICE HARVEST PRICE (Rs per Quintal) (100 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (100.0 ha)
#    Estimated Income: ₹1,283,933.93
# 117. MAIZE HARVEST PRICE (Rs per Quintal) (72 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,283,378.16
# 118. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (128 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (72.0 ha)
#    Estimated Income: ₹1,283,378.16
# 119. MAIZE HARVEST PRICE (Rs per Quintal) (68 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (132.0 ha)
#    Estimated Income: ₹1,278,247.93
# 120. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (132 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,278,247.93
# 121. MAIZE HARVEST PRICE (Rs per Quintal) (96 ha) + RICE HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,277,389.46
# 122. RICE HARVEST PRICE (Rs per Quintal) (104 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (96.0 ha)
#    Estimated Income: ₹1,277,389.46
# 123. MAIZE HARVEST PRICE (Rs per Quintal) (64 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (136.0 ha)
#    Estimated Income: ₹1,273,117.70
# 124. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (136 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (64.0 ha)
#    Estimated Income: ₹1,273,117.70
# 125. MAIZE HARVEST PRICE (Rs per Quintal) (92 ha) + RICE HARVEST PRICE (Rs per Quintal) (108.0 ha)
#    Estimated Income: ₹1,270,845.00
# 126. RICE HARVEST PRICE (Rs per Quintal) (108 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,270,845.00
# 127. MAIZE HARVEST PRICE (Rs per Quintal) (60 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,267,987.47
# 128. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (140 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (60.0 ha)
#    Estimated Income: ₹1,267,987.47
# 129. MAIZE HARVEST PRICE (Rs per Quintal) (88 ha) + RICE HARVEST PRICE (Rs per Quintal) (112.0 ha)
#    Estimated Income: ₹1,264,300.54
# 130. RICE HARVEST PRICE (Rs per Quintal) (112 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (88.0 ha)
#    Estimated Income: ₹1,264,300.54
# 131. MAIZE HARVEST PRICE (Rs per Quintal) (56 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (144.0 ha)
#    Estimated Income: ₹1,262,857.24
# 132. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (144 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,262,857.24
# 133. MAIZE HARVEST PRICE (Rs per Quintal) (84 ha) + RICE HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,257,756.07
# 134. RICE HARVEST PRICE (Rs per Quintal) (116 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (84.0 ha)
#    Estimated Income: ₹1,257,756.07
# 135. MAIZE HARVEST PRICE (Rs per Quintal) (52 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (148.0 ha)
#    Estimated Income: ₹1,257,727.01
# 136. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (148 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (52.0 ha)
#    Estimated Income: ₹1,257,727.01
# 137. MAIZE HARVEST PRICE (Rs per Quintal) (48 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,252,596.78
# 138. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (152 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (48.0 ha)
#    Estimated Income: ₹1,252,596.78
# 139. MAIZE HARVEST PRICE (Rs per Quintal) (80 ha) + RICE HARVEST PRICE (Rs per Quintal) (120.0 ha)
#    Estimated Income: ₹1,251,211.61
# 140. RICE HARVEST PRICE (Rs per Quintal) (120 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,251,211.61
# 141. MAIZE HARVEST PRICE (Rs per Quintal) (44 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (156.0 ha)
#    Estimated Income: ₹1,247,466.55
# 142. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (156 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,247,466.55
# 143. MAIZE HARVEST PRICE (Rs per Quintal) (76 ha) + RICE HARVEST PRICE (Rs per Quintal) (124.0 ha)
#    Estimated Income: ₹1,244,667.14
# 144. RICE HARVEST PRICE (Rs per Quintal) (124 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (76.0 ha)
#    Estimated Income: ₹1,244,667.14
# 145. MAIZE HARVEST PRICE (Rs per Quintal) (40 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (160.0 ha)
#    Estimated Income: ₹1,242,336.32
# 146. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (160 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (40.0 ha)
#    Estimated Income: ₹1,242,336.32
# 147. MAIZE HARVEST PRICE (Rs per Quintal) (72 ha) + RICE HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,238,122.68
# 148. RICE HARVEST PRICE (Rs per Quintal) (128 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (72.0 ha)
#    Estimated Income: ₹1,238,122.68
# 149. MAIZE HARVEST PRICE (Rs per Quintal) (36 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,237,206.09
# 150. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (164 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (36.0 ha)
#    Estimated Income: ₹1,237,206.09
# 151. MAIZE HARVEST PRICE (Rs per Quintal) (32 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (168.0 ha)
#    Estimated Income: ₹1,232,075.86
# 152. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (168 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,232,075.86
# 153. MAIZE HARVEST PRICE (Rs per Quintal) (68 ha) + RICE HARVEST PRICE (Rs per Quintal) (132.0 ha)
#    Estimated Income: ₹1,231,578.21
# 154. RICE HARVEST PRICE (Rs per Quintal) (132 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,231,578.21
# 155. MAIZE HARVEST PRICE (Rs per Quintal) (28 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (172.0 ha)
#    Estimated Income: ₹1,226,945.63
# 156. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (172 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (28.0 ha)
#    Estimated Income: ₹1,226,945.63
# 157. MAIZE HARVEST PRICE (Rs per Quintal) (64 ha) + RICE HARVEST PRICE (Rs per Quintal) (136.0 ha)
#    Estimated Income: ₹1,225,033.75
# 158. RICE HARVEST PRICE (Rs per Quintal) (136 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (64.0 ha)
#    Estimated Income: ₹1,225,033.75
# 159. MAIZE HARVEST PRICE (Rs per Quintal) (24 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,221,815.39
# 160. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (176 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (24.0 ha)
#    Estimated Income: ₹1,221,815.39
# 161. MAIZE HARVEST PRICE (Rs per Quintal) (60 ha) + RICE HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,218,489.28
# 162. RICE HARVEST PRICE (Rs per Quintal) (140 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (60.0 ha)
#    Estimated Income: ₹1,218,489.28
# 163. MAIZE HARVEST PRICE (Rs per Quintal) (20 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (180.0 ha)
#    Estimated Income: ₹1,216,685.16
# 164. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (180 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,216,685.16
# 165. MAIZE HARVEST PRICE (Rs per Quintal) (56 ha) + RICE HARVEST PRICE (Rs per Quintal) (144.0 ha)
#    Estimated Income: ₹1,211,944.82
# 166. RICE HARVEST PRICE (Rs per Quintal) (144 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,211,944.82
# 167. MAIZE HARVEST PRICE (Rs per Quintal) (16 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (184.0 ha)
#    Estimated Income: ₹1,211,554.93
# 168. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (184 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (16.0 ha)
#    Estimated Income: ₹1,211,554.93
# 169. MAIZE HARVEST PRICE (Rs per Quintal) (12 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,206,424.70
# 170. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (188 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (12.0 ha)
#    Estimated Income: ₹1,206,424.70
# 171. MAIZE HARVEST PRICE (Rs per Quintal) (52 ha) + RICE HARVEST PRICE (Rs per Quintal) (148.0 ha)
#    Estimated Income: ₹1,205,400.35
# 172. RICE HARVEST PRICE (Rs per Quintal) (148 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (52.0 ha)
#    Estimated Income: ₹1,205,400.35
# 173. MAIZE HARVEST PRICE (Rs per Quintal) (8 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (192.0 ha)
#    Estimated Income: ₹1,201,294.47
# 174. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (192 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,201,294.47
# 175. MAIZE HARVEST PRICE (Rs per Quintal) (48 ha) + RICE HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,198,855.89
# 176. RICE HARVEST PRICE (Rs per Quintal) (152 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (48.0 ha)
#    Estimated Income: ₹1,198,855.89
# 177. MAIZE HARVEST PRICE (Rs per Quintal) (4 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (196.0 ha)
#    Estimated Income: ₹1,196,164.24
# 178. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (196 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (4.0 ha)
#    Estimated Income: ₹1,196,164.24
# 179. MAIZE HARVEST PRICE (Rs per Quintal) (44 ha) + RICE HARVEST PRICE (Rs per Quintal) (156.0 ha)
#    Estimated Income: ₹1,192,311.43
# 180. RICE HARVEST PRICE (Rs per Quintal) (156 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,192,311.43
# 181. MAIZE HARVEST PRICE (Rs per Quintal) (0 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,191,034.01
# 182. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,191,034.01
# 183. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (200 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Estimated Income: ₹1,191,034.01
# 184. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (200 ha) + RICE HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Estimated Income: ₹1,191,034.01
# 185. RICE HARVEST PRICE (Rs per Quintal) (4 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (196.0 ha)
#    Estimated Income: ₹1,189,619.78
# 186. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (196 ha) + RICE HARVEST PRICE (Rs per Quintal) (4.0 ha)
#    Estimated Income: ₹1,189,619.78
# 187. RICE HARVEST PRICE (Rs per Quintal) (8 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (192.0 ha)
#    Estimated Income: ₹1,188,205.54
# 188. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (192 ha) + RICE HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,188,205.54
# 189. RICE HARVEST PRICE (Rs per Quintal) (12 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,186,791.31
# 190. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (188 ha) + RICE HARVEST PRICE (Rs per Quintal) (12.0 ha)
#    Estimated Income: ₹1,186,791.31
# 191. MAIZE HARVEST PRICE (Rs per Quintal) (40 ha) + RICE HARVEST PRICE (Rs per Quintal) (160.0 ha)
#    Estimated Income: ₹1,185,766.96
# 192. RICE HARVEST PRICE (Rs per Quintal) (160 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (40.0 ha)
#    Estimated Income: ₹1,185,766.96
# 193. RICE HARVEST PRICE (Rs per Quintal) (16 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (184.0 ha)
#    Estimated Income: ₹1,185,377.08
# 194. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (184 ha) + RICE HARVEST PRICE (Rs per Quintal) (16.0 ha)
#    Estimated Income: ₹1,185,377.08
# 195. RICE HARVEST PRICE (Rs per Quintal) (20 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (180.0 ha)
#    Estimated Income: ₹1,183,962.84
# 196. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (180 ha) + RICE HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,183,962.84
# 197. RICE HARVEST PRICE (Rs per Quintal) (24 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,182,548.61
# 198. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (176 ha) + RICE HARVEST PRICE (Rs per Quintal) (24.0 ha)
#    Estimated Income: ₹1,182,548.61
# 199. RICE HARVEST PRICE (Rs per Quintal) (28 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (172.0 ha)
#    Estimated Income: ₹1,181,134.37
# 200. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (172 ha) + RICE HARVEST PRICE (Rs per Quintal) (28.0 ha)
#    Estimated Income: ₹1,181,134.37
# 201. RICE HARVEST PRICE (Rs per Quintal) (32 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (168.0 ha)
#    Estimated Income: ₹1,179,720.14
# 202. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (168 ha) + RICE HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,179,720.14
# 203. MAIZE HARVEST PRICE (Rs per Quintal) (36 ha) + RICE HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,179,222.50
# 204. RICE HARVEST PRICE (Rs per Quintal) (164 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (36.0 ha)
#    Estimated Income: ₹1,179,222.50
# 205. RICE HARVEST PRICE (Rs per Quintal) (36 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,178,305.91
# 206. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (164 ha) + RICE HARVEST PRICE (Rs per Quintal) (36.0 ha)
#    Estimated Income: ₹1,178,305.91
# 207. RICE HARVEST PRICE (Rs per Quintal) (40 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (160.0 ha)
#    Estimated Income: ₹1,176,891.67
# 208. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (160 ha) + RICE HARVEST PRICE (Rs per Quintal) (40.0 ha)
#    Estimated Income: ₹1,176,891.67
# 209. RICE HARVEST PRICE (Rs per Quintal) (44 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (156.0 ha)
#    Estimated Income: ₹1,175,477.44
# 210. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (156 ha) + RICE HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,175,477.44
# 211. RICE HARVEST PRICE (Rs per Quintal) (48 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,174,063.20
# 212. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (152 ha) + RICE HARVEST PRICE (Rs per Quintal) (48.0 ha)
#    Estimated Income: ₹1,174,063.20
# 213. MAIZE HARVEST PRICE (Rs per Quintal) (32 ha) + RICE HARVEST PRICE (Rs per Quintal) (168.0 ha)
#    Estimated Income: ₹1,172,678.03
# 214. RICE HARVEST PRICE (Rs per Quintal) (168 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,172,678.03
# 215. RICE HARVEST PRICE (Rs per Quintal) (52 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (148.0 ha)
#    Estimated Income: ₹1,172,648.97
# 216. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (148 ha) + RICE HARVEST PRICE (Rs per Quintal) (52.0 ha)
#    Estimated Income: ₹1,172,648.97
# 217. RICE HARVEST PRICE (Rs per Quintal) (56 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (144.0 ha)
#    Estimated Income: ₹1,171,234.74
# 218. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (144 ha) + RICE HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,171,234.74
# 219. RICE HARVEST PRICE (Rs per Quintal) (60 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,169,820.50
# 220. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (140 ha) + RICE HARVEST PRICE (Rs per Quintal) (60.0 ha)
#    Estimated Income: ₹1,169,820.50
# 221. RICE HARVEST PRICE (Rs per Quintal) (64 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (136.0 ha)
#    Estimated Income: ₹1,168,406.27
# 222. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (136 ha) + RICE HARVEST PRICE (Rs per Quintal) (64.0 ha)
#    Estimated Income: ₹1,168,406.27
# 223. RICE HARVEST PRICE (Rs per Quintal) (68 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (132.0 ha)
#    Estimated Income: ₹1,166,992.03
# 224. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (132 ha) + RICE HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,166,992.03
# 225. MAIZE HARVEST PRICE (Rs per Quintal) (28 ha) + RICE HARVEST PRICE (Rs per Quintal) (172.0 ha)
#    Estimated Income: ₹1,166,133.57
# 226. RICE HARVEST PRICE (Rs per Quintal) (172 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (28.0 ha)
#    Estimated Income: ₹1,166,133.57
# 227. RICE HARVEST PRICE (Rs per Quintal) (72 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,165,577.80
# 228. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (128 ha) + RICE HARVEST PRICE (Rs per Quintal) (72.0 ha)
#    Estimated Income: ₹1,165,577.80
# 229. RICE HARVEST PRICE (Rs per Quintal) (76 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (124.0 ha)
#    Estimated Income: ₹1,164,163.57
# 230. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (124 ha) + RICE HARVEST PRICE (Rs per Quintal) (76.0 ha)
#    Estimated Income: ₹1,164,163.57
# 231. RICE HARVEST PRICE (Rs per Quintal) (80 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (120.0 ha)
#    Estimated Income: ₹1,162,749.33
# 232. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (120 ha) + RICE HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,162,749.33
# 233. RICE HARVEST PRICE (Rs per Quintal) (84 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,161,335.10
# 234. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (116 ha) + RICE HARVEST PRICE (Rs per Quintal) (84.0 ha)
#    Estimated Income: ₹1,161,335.10
# 235. RICE HARVEST PRICE (Rs per Quintal) (88 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (112.0 ha)
#    Estimated Income: ₹1,159,920.87
# 236. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (112 ha) + RICE HARVEST PRICE (Rs per Quintal) (88.0 ha)
#    Estimated Income: ₹1,159,920.87
# 237. MAIZE HARVEST PRICE (Rs per Quintal) (24 ha) + RICE HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,159,589.10
# 238. RICE HARVEST PRICE (Rs per Quintal) (176 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (24.0 ha)
#    Estimated Income: ₹1,159,589.10
# 239. RICE HARVEST PRICE (Rs per Quintal) (92 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (108.0 ha)
#    Estimated Income: ₹1,158,506.63
# 240. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (108 ha) + RICE HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,158,506.63
# 241. RICE HARVEST PRICE (Rs per Quintal) (96 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,157,092.40
# 242. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (104 ha) + RICE HARVEST PRICE (Rs per Quintal) (96.0 ha)
#    Estimated Income: ₹1,157,092.40
# 243. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (100 ha) + RICE HARVEST PRICE (Rs per Quintal) (100.0 ha)
#    Estimated Income: ₹1,155,678.16
# 244. RICE HARVEST PRICE (Rs per Quintal) (100 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (100.0 ha)
#    Estimated Income: ₹1,155,678.16
# 245. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (96 ha) + RICE HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,154,263.93
# 246. RICE HARVEST PRICE (Rs per Quintal) (104 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (96.0 ha)
#    Estimated Income: ₹1,154,263.93
# 247. MAIZE HARVEST PRICE (Rs per Quintal) (20 ha) + RICE HARVEST PRICE (Rs per Quintal) (180.0 ha)
#    Estimated Income: ₹1,153,044.64
# 248. RICE HARVEST PRICE (Rs per Quintal) (180 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,153,044.64
# 249. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (92 ha) + RICE HARVEST PRICE (Rs per Quintal) (108.0 ha)
#    Estimated Income: ₹1,152,849.70
# 250. RICE HARVEST PRICE (Rs per Quintal) (108 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,152,849.70
# 251. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (88 ha) + RICE HARVEST PRICE (Rs per Quintal) (112.0 ha)
#    Estimated Income: ₹1,151,435.46
# 252. RICE HARVEST PRICE (Rs per Quintal) (112 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (88.0 ha)
#    Estimated Income: ₹1,151,435.46
# 253. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (84 ha) + RICE HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,150,021.23
# 254. RICE HARVEST PRICE (Rs per Quintal) (116 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (84.0 ha)
#    Estimated Income: ₹1,150,021.23
# 255. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (80 ha) + RICE HARVEST PRICE (Rs per Quintal) (120.0 ha)
#    Estimated Income: ₹1,148,606.99
# 256. RICE HARVEST PRICE (Rs per Quintal) (120 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,148,606.99
# 257. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (76 ha) + RICE HARVEST PRICE (Rs per Quintal) (124.0 ha)
#    Estimated Income: ₹1,147,192.76
# 258. RICE HARVEST PRICE (Rs per Quintal) (124 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (76.0 ha)
#    Estimated Income: ₹1,147,192.76
# 259. MAIZE HARVEST PRICE (Rs per Quintal) (16 ha) + RICE HARVEST PRICE (Rs per Quintal) (184.0 ha)
#    Estimated Income: ₹1,146,500.17
# 260. RICE HARVEST PRICE (Rs per Quintal) (184 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (16.0 ha)
#    Estimated Income: ₹1,146,500.17
# 261. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (72 ha) + RICE HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,145,778.53
# 262. RICE HARVEST PRICE (Rs per Quintal) (128 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (72.0 ha)
#    Estimated Income: ₹1,145,778.53
# 263. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (68 ha) + RICE HARVEST PRICE (Rs per Quintal) (132.0 ha)
#    Estimated Income: ₹1,144,364.29
# 264. RICE HARVEST PRICE (Rs per Quintal) (132 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,144,364.29
# 265. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (64 ha) + RICE HARVEST PRICE (Rs per Quintal) (136.0 ha)
#    Estimated Income: ₹1,142,950.06
# 266. RICE HARVEST PRICE (Rs per Quintal) (136 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (64.0 ha)
#    Estimated Income: ₹1,142,950.06
# 267. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (60 ha) + RICE HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,141,535.82
# 268. RICE HARVEST PRICE (Rs per Quintal) (140 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (60.0 ha)
#    Estimated Income: ₹1,141,535.82
# 269. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (56 ha) + RICE HARVEST PRICE (Rs per Quintal) (144.0 ha)
#    Estimated Income: ₹1,140,121.59
# 270. RICE HARVEST PRICE (Rs per Quintal) (144 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,140,121.59
# 271. MAIZE HARVEST PRICE (Rs per Quintal) (12 ha) + RICE HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,139,955.71
# 272. RICE HARVEST PRICE (Rs per Quintal) (188 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (12.0 ha)
#    Estimated Income: ₹1,139,955.71
# 273. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (52 ha) + RICE HARVEST PRICE (Rs per Quintal) (148.0 ha)
#    Estimated Income: ₹1,138,707.36
# 274. RICE HARVEST PRICE (Rs per Quintal) (148 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (52.0 ha)
#    Estimated Income: ₹1,138,707.36
# 275. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (48 ha) + RICE HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,137,293.12
# 276. RICE HARVEST PRICE (Rs per Quintal) (152 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (48.0 ha)
#    Estimated Income: ₹1,137,293.12
# 277. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (44 ha) + RICE HARVEST PRICE (Rs per Quintal) (156.0 ha)
#    Estimated Income: ₹1,135,878.89
# 278. RICE HARVEST PRICE (Rs per Quintal) (156 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,135,878.89
# 279. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (40 ha) + RICE HARVEST PRICE (Rs per Quintal) (160.0 ha)
#    Estimated Income: ₹1,134,464.65
# 280. RICE HARVEST PRICE (Rs per Quintal) (160 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (40.0 ha)
#    Estimated Income: ₹1,134,464.65
# 281. MAIZE HARVEST PRICE (Rs per Quintal) (8 ha) + RICE HARVEST PRICE (Rs per Quintal) (192.0 ha)
#    Estimated Income: ₹1,133,411.24
# 282. RICE HARVEST PRICE (Rs per Quintal) (192 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,133,411.24
# 283. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (36 ha) + RICE HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,133,050.42
# 284. RICE HARVEST PRICE (Rs per Quintal) (164 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (36.0 ha)
#    Estimated Income: ₹1,133,050.42
# 285. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (32 ha) + RICE HARVEST PRICE (Rs per Quintal) (168.0 ha)
#    Estimated Income: ₹1,131,636.19
# 286. RICE HARVEST PRICE (Rs per Quintal) (168 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,131,636.19
# 287. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (28 ha) + RICE HARVEST PRICE (Rs per Quintal) (172.0 ha)
#    Estimated Income: ₹1,130,221.95
# 288. RICE HARVEST PRICE (Rs per Quintal) (172 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (28.0 ha)
#    Estimated Income: ₹1,130,221.95
# 289. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (24 ha) + RICE HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,128,807.72
# 290. RICE HARVEST PRICE (Rs per Quintal) (176 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (24.0 ha)
#    Estimated Income: ₹1,128,807.72
# 291. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (20 ha) + RICE HARVEST PRICE (Rs per Quintal) (180.0 ha)
#    Estimated Income: ₹1,127,393.49
# 292. RICE HARVEST PRICE (Rs per Quintal) (180 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,127,393.49
# 293. MAIZE HARVEST PRICE (Rs per Quintal) (4 ha) + RICE HARVEST PRICE (Rs per Quintal) (196.0 ha)
#    Estimated Income: ₹1,126,866.78
# 294. RICE HARVEST PRICE (Rs per Quintal) (196 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (4.0 ha)
#    Estimated Income: ₹1,126,866.78
# 295. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (16 ha) + RICE HARVEST PRICE (Rs per Quintal) (184.0 ha)
#    Estimated Income: ₹1,125,979.25
# 296. RICE HARVEST PRICE (Rs per Quintal) (184 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (16.0 ha)
#    Estimated Income: ₹1,125,979.25
# 297. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (12 ha) + RICE HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,124,565.02
# 298. RICE HARVEST PRICE (Rs per Quintal) (188 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (12.0 ha)
#    Estimated Income: ₹1,124,565.02
# 299. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (8 ha) + RICE HARVEST PRICE (Rs per Quintal) (192.0 ha)
#    Estimated Income: ₹1,123,150.78
# 300. RICE HARVEST PRICE (Rs per Quintal) (192 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,123,150.78
# 301. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (4 ha) + RICE HARVEST PRICE (Rs per Quintal) (196.0 ha)
#    Estimated Income: ₹1,121,736.55
# 302. RICE HARVEST PRICE (Rs per Quintal) (196 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (4.0 ha)
#    Estimated Income: ₹1,121,736.55
# 303. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + RICE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,120,322.32
# 304. MAIZE HARVEST PRICE (Rs per Quintal) (0 ha) + RICE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,120,322.32
# 305. RICE HARVEST PRICE (Rs per Quintal) (200 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Estimated Income: ₹1,120,322.32
# 306. RICE HARVEST PRICE (Rs per Quintal) (200 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Estimated Income: ₹1,120,322.32
#
# Top 5 Crop Combinations for Maximum Income:
# 1. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,447,545.54
# 2. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,447,545.54
# 3. MAIZE HARVEST PRICE (Rs per Quintal) (200 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Estimated Income: ₹1,447,545.54
# 4. MAIZE HARVEST PRICE (Rs per Quintal) (200 ha) + RICE HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Estimated Income: ₹1,447,545.54
# 5. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (4 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (196.0 ha)
#    Estimated Income: ₹1,442,415.31
#
# Optimal Crop Combination for Maximum Revenue:
# 1. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Maximum Estimated Income: ₹1,447,545.54
#    Soil Suitability: COTTON KAPAS (0.00%), MAIZE (0.00%)
# 2. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Maximum Estimated Income: ₹1,447,545.54
#    Soil Suitability: RICE (0.00%), MAIZE (0.00%)
# 3. MAIZE HARVEST PRICE (Rs per Quintal) (200 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Maximum Estimated Income: ₹1,447,545.54
#    Soil Suitability: MAIZE (0.00%), COTTON KAPAS (0.00%)
# 4. MAIZE HARVEST PRICE (Rs per Quintal) (200 ha) + RICE HARVEST PRICE (Rs per Quintal) (0.0 ha)
#    Maximum Estimated Income: ₹1,447,545.54
#    Soil Suitability: MAIZE (0.00%), RICE (0.00%)
# c:\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import itertools


crop_df = pd.read_csv('data.csv')
yield_df = pd.read_csv('commodity_yield.csv')
icrisat_df = pd.read_csv('ICRISAT-District Level Data.csv')
price_df = pd.read_csv('pricesdataset.csv')

def preprocess_data():
    """Extract crop price data from ICRISAT dataset."""
    price_columns = [col for col in icrisat_df.columns if 'HARVEST PRICE' in col]
    crop_prices = {}
    
    for column in price_columns:
        crop_name = column.split(' HARVEST')[0].strip()
        crop_prices[crop_name] = icrisat_df[column].mean()
    
    return crop_prices, price_columns

def get_suitable_crops(n, p, k, temp, humidity, ph, rainfall):
    """Find suitable crops based on soil parameters using KNN."""
    X = crop_df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
    y = crop_df['label']
    
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X, y)
    
    farm_conditions = [n, p, k, temp, humidity, ph, rainfall]
    probabilities = knn.predict_proba([farm_conditions])[0]
    crops = knn.classes_
    
    # Return all crops with their suitability probability
    return sorted(zip(crops, probabilities), key=lambda x: x[1], reverse=True)

def match_crop_data(suitable_crops, yield_df, price_columns, crop_prices):
    """Match suitable crops with yield and price data."""
    crop_data = {}
    
    for crop_name, probability in suitable_crops:
        # Convert to uppercase for matching with ICRISAT columns
        crop_upper = crop_name.upper()
        
        # Find matching price column
        matching_columns = [col for col in price_columns if crop_upper in col]
        if not matching_columns:
            continue
            
        # Get yield data
        yield_values = yield_df[yield_df['Commodity'].str.lower() == crop_name.lower()]['Yield_Quintals_Per_Hectare'].values
        if len(yield_values) == 0:
            continue
            
        # Get the crop name from the price column
        icrisat_crop_name = matching_columns[0].split(' HARVEST')[0].strip()
        
        crop_data[icrisat_crop_name] = {
            'yield': yield_values[0],
            'price': crop_prices[icrisat_crop_name],
            'probability': probability
        }
    
    return crop_data

def generate_crop_combinations(crop_data, total_area=100, step_size=10):
    """Generate all crop combinations with variable area allocations."""
    combinations = []
    
    # Get all pairs of crops
    crop_pairs = list(itertools.permutations(crop_data.keys(), 2))
    
    # Try different area allocations with specified step size
    for area1 in range(0, int(total_area + 1), step_size):
        area2 = total_area - area1
        
        for crop1, crop2 in crop_pairs:
            # Calculate revenue
            revenue = (area1 * crop_data[crop1]['yield'] * crop_data[crop1]['price']) + \
                     (area2 * crop_data[crop2]['yield'] * crop_data[crop2]['price'])
            
            combinations.append({
                'crop1': crop1,
                'area1': area1,
                'crop2': crop2,
                'area2': area2,
                'revenue': revenue,
                'crop1_prob': crop_data[crop1]['probability'],
                'crop2_prob': crop_data[crop2]['probability']
            })
    
    # Sort by revenue in descending order
    combinations.sort(key=lambda x: x['revenue'], reverse=True)
    return combinations

def generate_top_suitable_crop_combinations(crop_data, top_suitable_crops, total_area=100, step_size=10):
    """Generate combinations using only the top suitable crops."""
    combinations = []
    
    # Filter to include only the top suitable crops
    suitable_crop_data = {crop: data for crop, data in crop_data.items() 
                         if crop.upper() in [c.upper() for c in top_suitable_crops]}
    
    # If we don't have enough suitable crops with data, return empty list
    if len(suitable_crop_data) < 2:
        return []
    
    # Get all pairs of these suitable crops
    crop_pairs = list(itertools.permutations(suitable_crop_data.keys(), 2))
    
    # Try different area allocations with specified step size
    for area1 in range(0, int(total_area + 1), step_size):
        area2 = total_area - area1
        
        for crop1, crop2 in crop_pairs:
            # Calculate revenue
            revenue = (area1 * suitable_crop_data[crop1]['yield'] * suitable_crop_data[crop1]['price']) + \
                     (area2 * suitable_crop_data[crop2]['yield'] * suitable_crop_data[crop2]['price'])
            
            combinations.append({
                'crop1': crop1,
                'area1': area1,
                'crop2': crop2,
                'area2': area2,
                'revenue': revenue,
                'crop1_prob': suitable_crop_data[crop1]['probability'],
                'crop2_prob': suitable_crop_data[crop2]['probability']
            })
    
    # Sort by revenue in descending order
    combinations.sort(key=lambda x: x['revenue'], reverse=True)
    return combinations

def main():
    """Main function to recommend and compare crop combinations."""
    # Input farm conditions and total land area
    print("Enter soil and climate parameters:")
    n = float(input("Enter Nitrogen (N) content (kg/ha): "))
    p = float(input("Enter Phosphorus (P) content (kg/ha): "))
    k = float(input("Enter Potassium (K) content (kg/ha): "))
    temp = float(input("Enter Temperature (°C): "))
    humidity = float(input("Enter Humidity (%): "))
    ph = float(input("Enter pH: "))
    rainfall = float(input("Enter Rainfall (mm): "))
    
    total_area = float(input("Enter total available area (hectares): "))
    step_size = int(input("Enter step size for area allocation (10 recommended): "))
    
    # Preprocess data
    crop_prices, price_columns = preprocess_data()
    
    # Get suitable crops based on soil parameters
    suitable_crops = get_suitable_crops(n, p, k, temp, humidity, ph, rainfall)
    
    print("\nRecommended Crops (In Order of Suitability):")
    for i, (crop, prob) in enumerate(suitable_crops[:10], 1):
        print(f"{i}. {crop.capitalize()}")
    
    # Get the names of the top 2 most suitable crops
    top_suitable_crop_names = [crop for crop, _ in suitable_crops[:2]]
    
    # Match all suitable crops with yield and price data
    crop_data = match_crop_data(suitable_crops, yield_df, price_columns, crop_prices)
    
    # Check if we have enough crop data
    if len(crop_data) < 2:
        print("Insufficient crop data. Please check the datasets or adjust soil parameters.")
        return
    
    # Generate all crop combinations with varying area allocations
    all_combinations = generate_crop_combinations(crop_data, total_area, step_size)
    
    # Generate combinations using only the top suitable crops
    suitable_combinations = generate_top_suitable_crop_combinations(crop_data, top_suitable_crop_names, total_area, step_size)
    
    # Display all tested combinations
    print("\nAll Tested Crop Combinations:")
    for i, combo in enumerate(all_combinations, 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Estimated Income: ₹{combo['revenue']:,.2f}")
    
    # Display the top 5 combinations for maximum revenue
    print("\nTop 5 Crop Combinations for Maximum Income (Regardless of Suitability):")
    for i, combo in enumerate(all_combinations[:5], 1):
        print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
        print(f"   Estimated Income: ₹{combo['revenue']:,.2f}")
        print(f"   Soil Suitability: {combo['crop1']} ({combo['crop1_prob']:.2%}), {combo['crop2']} ({combo['crop2_prob']:.2%})")
    
    # Display the best combinations from the most suitable crops
    if suitable_combinations:
        print("\nBest Combinations Using Top 2 Most Suitable Crops:")
        for i, combo in enumerate(suitable_combinations[:3], 1):
            print(f"{i}. {combo['crop1']} HARVEST PRICE (Rs per Quintal) ({combo['area1']} ha) + {combo['crop2']} HARVEST PRICE (Rs per Quintal) ({combo['area2']} ha)")
            print(f"   Estimated Income: ₹{combo['revenue']:,.2f}")
            print(f"   Soil Suitability: {combo['crop1']} ({combo['crop1_prob']:.2%}), {combo['crop2']} ({combo['crop2_prob']:.2%})")
    else:
        print("\nNo valid combinations found using the top 2 most suitable crops.")
    
    # Compare the highest revenue combination with the best suitable combination
    print("\nComparison for Farmer's Decision:")
    print("---------------------------------")
    if all_combinations:
        max_revenue_combo = all_combinations[0]
        print(f"Highest Revenue Combination:")
        print(f"Crops: {max_revenue_combo['crop1']} ({max_revenue_combo['area1']} ha) + {max_revenue_combo['crop2']} ({max_revenue_combo['area2']} ha)")
        print(f"Estimated Income: ₹{max_revenue_combo['revenue']:,.2f}")
        print(f"Soil Suitability: {max_revenue_combo['crop1']} ({max_revenue_combo['crop1_prob']:.2%}), {max_revenue_combo['crop2']} ({max_revenue_combo['crop2_prob']:.2%})")
    
    if suitable_combinations:
        best_suitable_combo = suitable_combinations[0]
        print(f"\nBest Combination from Most Suitable Crops:")
        print(f"Crops: {best_suitable_combo['crop1']} ({best_suitable_combo['area1']} ha) + {best_suitable_combo['crop2']} ({best_suitable_combo['area2']} ha)")
        print(f"Estimated Income: ₹{best_suitable_combo['revenue']:,.2f}")
        print(f"Soil Suitability: {best_suitable_combo['crop1']} ({best_suitable_combo['crop1_prob']:.2%}), {best_suitable_combo['crop2']} ({best_suitable_combo['crop2_prob']:.2%})")
        
        # Calculate the revenue difference
        if all_combinations:
            revenue_difference = max_revenue_combo['revenue'] - best_suitable_combo['revenue']
            percentage_difference = (revenue_difference / best_suitable_combo['revenue']) * 100
            
            print(f"\nRevenue Difference:")
            print(f"The highest revenue combination generates ₹{revenue_difference:,.2f} more than the most suitable combination.")
            print(f"This is {percentage_difference:.2f}% more income.")
            
            print("\nFarmer's Consideration:")
            print("While the highest revenue combination offers more income, the most suitable crops are better adapted to your soil conditions.")
            print("This may result in more consistent yields, lower input costs for soil amendments, and more sustainable farming in the long term.")
    else:
        print("\nNo valid combinations using the most suitable crops were found.")
        print("Consider improving soil conditions or exploring other crop options that may be both suitable and profitable.")

if __name__ == "__main__":
    main()
# Out:
# Enter soil and climate parameters:
#
# Recommended Crops (In Order of Suitability):
# 1. Pigeonpeas (Suitability: 100.00%)
# 2. Apple (Suitability: 0.00%)
# 3. Banana (Suitability: 0.00%)
# 4. Blackgram (Suitability: 0.00%)
# 5. Chickpea (Suitability: 0.00%)
# 6. Coconut (Suitability: 0.00%)
# 7. Coffee (Suitability: 0.00%)
# 8. Cotton (Suitability: 0.00%)
# 9. Grapes (Suitability: 0.00%)
# 10. Jute (Suitability: 0.00%)
#
# All Tested Crop Combinations:
# 1. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,447,545.54
# 2. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,447,545.54
# 3. MAIZE HARVEST PRICE (Rs per Quintal) (198 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (2.0 ha)
#    Estimated Income: ₹1,444,980.43
# 4. MAIZE HARVEST PRICE (Rs per Quintal) (198 ha) + RICE HARVEST PRICE (Rs per Quintal) (2.0 ha)
#    Estimated Income: ₹1,444,273.31
# 5. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (6 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (194.0 ha)
#    Estimated Income: ₹1,439,850.20
# 6. RICE HARVEST PRICE (Rs per Quintal) (6 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (194.0 ha)
#    Estimated Income: ₹1,437,728.84
# 7. MAIZE HARVEST PRICE (Rs per Quintal) (192 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,437,285.08
# 8. MAIZE HARVEST PRICE (Rs per Quintal) (192 ha) + RICE HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,434,456.61
# 9. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (12 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,432,154.85
# 10. MAIZE HARVEST PRICE (Rs per Quintal) (186 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (14.0 ha)
#    Estimated Income: ₹1,429,589.73
# 11. RICE HARVEST PRICE (Rs per Quintal) (12 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,427,912.15
# 12. MAIZE HARVEST PRICE (Rs per Quintal) (186 ha) + RICE HARVEST PRICE (Rs per Quintal) (14.0 ha)
#    Estimated Income: ₹1,424,639.92
# 13. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (18 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (182.0 ha)
#    Estimated Income: ₹1,424,459.50
# 14. MAIZE HARVEST PRICE (Rs per Quintal) (180 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,421,894.39
# 15. RICE HARVEST PRICE (Rs per Quintal) (18 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (182.0 ha)
#    Estimated Income: ₹1,418,095.45
# 16. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (24 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,416,764.16
# 17. MAIZE HARVEST PRICE (Rs per Quintal) (180 ha) + RICE HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,414,823.22
# 18. MAIZE HARVEST PRICE (Rs per Quintal) (174 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (26.0 ha)
#    Estimated Income: ₹1,414,199.04
# 19. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (30 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (170.0 ha)
#    Estimated Income: ₹1,409,068.81
# 20. RICE HARVEST PRICE (Rs per Quintal) (24 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,408,278.75
# 21. MAIZE HARVEST PRICE (Rs per Quintal) (168 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,406,503.70
# 22. MAIZE HARVEST PRICE (Rs per Quintal) (174 ha) + RICE HARVEST PRICE (Rs per Quintal) (26.0 ha)
#    Estimated Income: ₹1,405,006.52
# 23. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (36 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,401,373.47
# 24. MAIZE HARVEST PRICE (Rs per Quintal) (162 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (38.0 ha)
#    Estimated Income: ₹1,398,808.35
# 25. RICE HARVEST PRICE (Rs per Quintal) (30 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (170.0 ha)
#    Estimated Income: ₹1,398,462.06
# 26. MAIZE HARVEST PRICE (Rs per Quintal) (168 ha) + RICE HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,395,189.83
# 27. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (42 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (158.0 ha)
#    Estimated Income: ₹1,393,678.12
# 28. MAIZE HARVEST PRICE (Rs per Quintal) (156 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,391,113.00
# 29. RICE HARVEST PRICE (Rs per Quintal) (36 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,388,645.36
# 30. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (48 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,385,982.77
# 31. MAIZE HARVEST PRICE (Rs per Quintal) (162 ha) + RICE HARVEST PRICE (Rs per Quintal) (38.0 ha)
#    Estimated Income: ₹1,385,373.13
# 32. MAIZE HARVEST PRICE (Rs per Quintal) (150 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (50.0 ha)
#    Estimated Income: ₹1,383,417.66
# 33. RICE HARVEST PRICE (Rs per Quintal) (42 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (158.0 ha)
#    Estimated Income: ₹1,378,828.66
# 34. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (54 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (146.0 ha)
#    Estimated Income: ₹1,378,287.43
# 35. MAIZE HARVEST PRICE (Rs per Quintal) (144 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,375,722.31
# 36. MAIZE HARVEST PRICE (Rs per Quintal) (156 ha) + RICE HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,375,556.43
# 37. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (60 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,370,592.08
# 38. RICE HARVEST PRICE (Rs per Quintal) (48 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,369,011.97
# 39. MAIZE HARVEST PRICE (Rs per Quintal) (138 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (62.0 ha)
#    Estimated Income: ₹1,368,026.97
# 40. MAIZE HARVEST PRICE (Rs per Quintal) (150 ha) + RICE HARVEST PRICE (Rs per Quintal) (50.0 ha)
#    Estimated Income: ₹1,365,739.73
# 41. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (66 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (134.0 ha)
#    Estimated Income: ₹1,362,896.74
# 42. MAIZE HARVEST PRICE (Rs per Quintal) (132 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,360,331.62
# 43. RICE HARVEST PRICE (Rs per Quintal) (54 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (146.0 ha)
#    Estimated Income: ₹1,359,195.27
# 44. MAIZE HARVEST PRICE (Rs per Quintal) (144 ha) + RICE HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,355,923.04
# 45. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (72 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,355,201.39
# 46. MAIZE HARVEST PRICE (Rs per Quintal) (126 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (74.0 ha)
#    Estimated Income: ₹1,352,636.28
# 47. RICE HARVEST PRICE (Rs per Quintal) (60 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,349,378.57
# 48. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (78 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (122.0 ha)
#    Estimated Income: ₹1,347,506.04
# 49. MAIZE HARVEST PRICE (Rs per Quintal) (138 ha) + RICE HARVEST PRICE (Rs per Quintal) (62.0 ha)
#    Estimated Income: ₹1,346,106.34
# 50. MAIZE HARVEST PRICE (Rs per Quintal) (120 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,344,940.93
# 51. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (84 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,339,810.70
# 52. RICE HARVEST PRICE (Rs per Quintal) (66 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (134.0 ha)
#    Estimated Income: ₹1,339,561.88
# 53. MAIZE HARVEST PRICE (Rs per Quintal) (114 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (86.0 ha)
#    Estimated Income: ₹1,337,245.58
# 54. MAIZE HARVEST PRICE (Rs per Quintal) (132 ha) + RICE HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,336,289.64
# 55. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (90 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (110.0 ha)
#    Estimated Income: ₹1,332,115.35
# 56. RICE HARVEST PRICE (Rs per Quintal) (72 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,329,745.18
# 57. MAIZE HARVEST PRICE (Rs per Quintal) (108 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,329,550.24
# 58. MAIZE HARVEST PRICE (Rs per Quintal) (126 ha) + RICE HARVEST PRICE (Rs per Quintal) (74.0 ha)
#    Estimated Income: ₹1,326,472.95
# 59. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (96 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,324,420.01
# 60. MAIZE HARVEST PRICE (Rs per Quintal) (102 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (98.0 ha)
#    Estimated Income: ₹1,321,854.89
# 61. RICE HARVEST PRICE (Rs per Quintal) (78 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (122.0 ha)
#    Estimated Income: ₹1,319,928.48
# 62. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (102 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (98.0 ha)
#    Estimated Income: ₹1,316,724.66
# 63. MAIZE HARVEST PRICE (Rs per Quintal) (120 ha) + RICE HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,316,656.25
# 64. MAIZE HARVEST PRICE (Rs per Quintal) (96 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,314,159.55
# 65. RICE HARVEST PRICE (Rs per Quintal) (84 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,310,111.79
# 66. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (108 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,309,029.32
# 67. MAIZE HARVEST PRICE (Rs per Quintal) (114 ha) + RICE HARVEST PRICE (Rs per Quintal) (86.0 ha)
#    Estimated Income: ₹1,306,839.55
# 68. MAIZE HARVEST PRICE (Rs per Quintal) (90 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (110.0 ha)
#    Estimated Income: ₹1,306,464.20
# 69. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (114 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (86.0 ha)
#    Estimated Income: ₹1,301,333.97
# 70. RICE HARVEST PRICE (Rs per Quintal) (90 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (110.0 ha)
#    Estimated Income: ₹1,300,295.09
# 71. MAIZE HARVEST PRICE (Rs per Quintal) (84 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,298,768.85
# 72. MAIZE HARVEST PRICE (Rs per Quintal) (108 ha) + RICE HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,297,022.86
# 73. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (120 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,293,638.62
# 74. MAIZE HARVEST PRICE (Rs per Quintal) (78 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (122.0 ha)
#    Estimated Income: ₹1,291,073.51
# 75. RICE HARVEST PRICE (Rs per Quintal) (96 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,290,478.39
# 76. MAIZE HARVEST PRICE (Rs per Quintal) (102 ha) + RICE HARVEST PRICE (Rs per Quintal) (98.0 ha)
#    Estimated Income: ₹1,287,206.16
# 77. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (126 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (74.0 ha)
#    Estimated Income: ₹1,285,943.28
# 78. MAIZE HARVEST PRICE (Rs per Quintal) (72 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,283,378.16
# 79. RICE HARVEST PRICE (Rs per Quintal) (102 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (98.0 ha)
#    Estimated Income: ₹1,280,661.70
# 80. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (132 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,278,247.93
# 81. MAIZE HARVEST PRICE (Rs per Quintal) (96 ha) + RICE HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,277,389.46
# 82. MAIZE HARVEST PRICE (Rs per Quintal) (66 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (134.0 ha)
#    Estimated Income: ₹1,275,682.82
# 83. RICE HARVEST PRICE (Rs per Quintal) (108 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,270,845.00
# 84. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (138 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (62.0 ha)
#    Estimated Income: ₹1,270,552.59
# 85. MAIZE HARVEST PRICE (Rs per Quintal) (60 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,267,987.47
# 86. MAIZE HARVEST PRICE (Rs per Quintal) (90 ha) + RICE HARVEST PRICE (Rs per Quintal) (110.0 ha)
#    Estimated Income: ₹1,267,572.77
# 87. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (144 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,262,857.24
# 88. RICE HARVEST PRICE (Rs per Quintal) (114 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (86.0 ha)
#    Estimated Income: ₹1,261,028.30
# 89. MAIZE HARVEST PRICE (Rs per Quintal) (54 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (146.0 ha)
#    Estimated Income: ₹1,260,292.12
# 90. MAIZE HARVEST PRICE (Rs per Quintal) (84 ha) + RICE HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,257,756.07
# 91. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (150 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (50.0 ha)
#    Estimated Income: ₹1,255,161.89
# 92. MAIZE HARVEST PRICE (Rs per Quintal) (48 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,252,596.78
# 93. RICE HARVEST PRICE (Rs per Quintal) (120 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,251,211.61
# 94. MAIZE HARVEST PRICE (Rs per Quintal) (78 ha) + RICE HARVEST PRICE (Rs per Quintal) (122.0 ha)
#    Estimated Income: ₹1,247,939.37
# 95. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (156 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,247,466.55
# 96. MAIZE HARVEST PRICE (Rs per Quintal) (42 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (158.0 ha)
#    Estimated Income: ₹1,244,901.43
# 97. RICE HARVEST PRICE (Rs per Quintal) (126 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (74.0 ha)
#    Estimated Income: ₹1,241,394.91
# 98. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (162 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (38.0 ha)
#    Estimated Income: ₹1,239,771.20
# 99. MAIZE HARVEST PRICE (Rs per Quintal) (72 ha) + RICE HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,238,122.68
# 100. MAIZE HARVEST PRICE (Rs per Quintal) (36 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,237,206.09
# 101. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (168 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,232,075.86
# 102. RICE HARVEST PRICE (Rs per Quintal) (132 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,231,578.21
# 103. MAIZE HARVEST PRICE (Rs per Quintal) (30 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (170.0 ha)
#    Estimated Income: ₹1,229,510.74
# 104. MAIZE HARVEST PRICE (Rs per Quintal) (66 ha) + RICE HARVEST PRICE (Rs per Quintal) (134.0 ha)
#    Estimated Income: ₹1,228,305.98
# 105. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (174 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (26.0 ha)
#    Estimated Income: ₹1,224,380.51
# 106. MAIZE HARVEST PRICE (Rs per Quintal) (24 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,221,815.39
# 107. RICE HARVEST PRICE (Rs per Quintal) (138 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (62.0 ha)
#    Estimated Income: ₹1,221,761.52
# 108. MAIZE HARVEST PRICE (Rs per Quintal) (60 ha) + RICE HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,218,489.28
# 109. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (180 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,216,685.16
# 110. MAIZE HARVEST PRICE (Rs per Quintal) (18 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (182.0 ha)
#    Estimated Income: ₹1,214,120.05
# 111. RICE HARVEST PRICE (Rs per Quintal) (144 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,211,944.82
# 112. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (186 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (14.0 ha)
#    Estimated Income: ₹1,208,989.82
# 113. MAIZE HARVEST PRICE (Rs per Quintal) (54 ha) + RICE HARVEST PRICE (Rs per Quintal) (146.0 ha)
#    Estimated Income: ₹1,208,672.59
# 114. MAIZE HARVEST PRICE (Rs per Quintal) (12 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,206,424.70
# 115. RICE HARVEST PRICE (Rs per Quintal) (150 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (50.0 ha)
#    Estimated Income: ₹1,202,128.12
# 116. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (192 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,201,294.47
# 117. MAIZE HARVEST PRICE (Rs per Quintal) (48 ha) + RICE HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,198,855.89
# 118. MAIZE HARVEST PRICE (Rs per Quintal) (6 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (194.0 ha)
#    Estimated Income: ₹1,198,729.36
# 119. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (198 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (2.0 ha)
#    Estimated Income: ₹1,193,599.13
# 120. RICE HARVEST PRICE (Rs per Quintal) (156 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,192,311.43
# 121. MAIZE HARVEST PRICE (Rs per Quintal) (0 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,191,034.01
# 122. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,191,034.01
# 123. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (198 ha) + RICE HARVEST PRICE (Rs per Quintal) (2.0 ha)
#    Estimated Income: ₹1,190,326.89
# 124. MAIZE HARVEST PRICE (Rs per Quintal) (42 ha) + RICE HARVEST PRICE (Rs per Quintal) (158.0 ha)
#    Estimated Income: ₹1,189,039.19
# 125. RICE HARVEST PRICE (Rs per Quintal) (6 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (194.0 ha)
#    Estimated Income: ₹1,188,912.66
# 126. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (192 ha) + RICE HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,188,205.54
# 127. RICE HARVEST PRICE (Rs per Quintal) (12 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,186,791.31
# 128. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (186 ha) + RICE HARVEST PRICE (Rs per Quintal) (14.0 ha)
#    Estimated Income: ₹1,186,084.19
# 129. RICE HARVEST PRICE (Rs per Quintal) (18 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (182.0 ha)
#    Estimated Income: ₹1,184,669.96
# 130. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (180 ha) + RICE HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,183,962.84
# 131. RICE HARVEST PRICE (Rs per Quintal) (24 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,182,548.61
# 132. RICE HARVEST PRICE (Rs per Quintal) (162 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (38.0 ha)
#    Estimated Income: ₹1,182,494.73
# 133. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (174 ha) + RICE HARVEST PRICE (Rs per Quintal) (26.0 ha)
#    Estimated Income: ₹1,181,841.49
# 134. RICE HARVEST PRICE (Rs per Quintal) (30 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (170.0 ha)
#    Estimated Income: ₹1,180,427.26
# 135. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (168 ha) + RICE HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,179,720.14
# 136. MAIZE HARVEST PRICE (Rs per Quintal) (36 ha) + RICE HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,179,222.50
# 137. RICE HARVEST PRICE (Rs per Quintal) (36 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,178,305.91
# 138. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (162 ha) + RICE HARVEST PRICE (Rs per Quintal) (38.0 ha)
#    Estimated Income: ₹1,177,598.79
# 139. RICE HARVEST PRICE (Rs per Quintal) (42 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (158.0 ha)
#    Estimated Income: ₹1,176,184.56
# 140. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (156 ha) + RICE HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,175,477.44
# 141. RICE HARVEST PRICE (Rs per Quintal) (48 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,174,063.20
# 142. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (150 ha) + RICE HARVEST PRICE (Rs per Quintal) (50.0 ha)
#    Estimated Income: ₹1,173,356.09
# 143. RICE HARVEST PRICE (Rs per Quintal) (168 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,172,678.03
# 144. RICE HARVEST PRICE (Rs per Quintal) (54 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (146.0 ha)
#    Estimated Income: ₹1,171,941.85
# 145. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (144 ha) + RICE HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,171,234.74
# 146. RICE HARVEST PRICE (Rs per Quintal) (60 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,169,820.50
# 147. MAIZE HARVEST PRICE (Rs per Quintal) (30 ha) + RICE HARVEST PRICE (Rs per Quintal) (170.0 ha)
#    Estimated Income: ₹1,169,405.80
# 148. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (138 ha) + RICE HARVEST PRICE (Rs per Quintal) (62.0 ha)
#    Estimated Income: ₹1,169,113.39
# 149. RICE HARVEST PRICE (Rs per Quintal) (66 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (134.0 ha)
#    Estimated Income: ₹1,167,699.15
# 150. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (132 ha) + RICE HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,166,992.03
# 151. RICE HARVEST PRICE (Rs per Quintal) (72 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,165,577.80
# 152. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (126 ha) + RICE HARVEST PRICE (Rs per Quintal) (74.0 ha)
#    Estimated Income: ₹1,164,870.68
# 153. RICE HARVEST PRICE (Rs per Quintal) (78 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (122.0 ha)
#    Estimated Income: ₹1,163,456.45
# 154. RICE HARVEST PRICE (Rs per Quintal) (174 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (26.0 ha)
#    Estimated Income: ₹1,162,861.34
# 155. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (120 ha) + RICE HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,162,749.33
# 156. RICE HARVEST PRICE (Rs per Quintal) (84 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,161,335.10
# 157. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (114 ha) + RICE HARVEST PRICE (Rs per Quintal) (86.0 ha)
#    Estimated Income: ₹1,160,627.98
# 158. MAIZE HARVEST PRICE (Rs per Quintal) (24 ha) + RICE HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,159,589.10
# 159. RICE HARVEST PRICE (Rs per Quintal) (90 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (110.0 ha)
#    Estimated Income: ₹1,159,213.75
# 160. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (108 ha) + RICE HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,158,506.63
# 161. RICE HARVEST PRICE (Rs per Quintal) (96 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,157,092.40
# 162. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (102 ha) + RICE HARVEST PRICE (Rs per Quintal) (98.0 ha)
#    Estimated Income: ₹1,156,385.28
# 163. RICE HARVEST PRICE (Rs per Quintal) (102 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (98.0 ha)
#    Estimated Income: ₹1,154,971.05
# 164. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (96 ha) + RICE HARVEST PRICE (Rs per Quintal) (104.0 ha)
#    Estimated Income: ₹1,154,263.93
# 165. RICE HARVEST PRICE (Rs per Quintal) (180 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,153,044.64
# 166. RICE HARVEST PRICE (Rs per Quintal) (108 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (92.0 ha)
#    Estimated Income: ₹1,152,849.70
# 167. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (90 ha) + RICE HARVEST PRICE (Rs per Quintal) (110.0 ha)
#    Estimated Income: ₹1,152,142.58
# 168. RICE HARVEST PRICE (Rs per Quintal) (114 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (86.0 ha)
#    Estimated Income: ₹1,150,728.34
# 169. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (84 ha) + RICE HARVEST PRICE (Rs per Quintal) (116.0 ha)
#    Estimated Income: ₹1,150,021.23
# 170. MAIZE HARVEST PRICE (Rs per Quintal) (18 ha) + RICE HARVEST PRICE (Rs per Quintal) (182.0 ha)
#    Estimated Income: ₹1,149,772.41
# 171. RICE HARVEST PRICE (Rs per Quintal) (120 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (80.0 ha)
#    Estimated Income: ₹1,148,606.99
# 172. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (78 ha) + RICE HARVEST PRICE (Rs per Quintal) (122.0 ha)
#    Estimated Income: ₹1,147,899.88
# 173. RICE HARVEST PRICE (Rs per Quintal) (126 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (74.0 ha)
#    Estimated Income: ₹1,146,485.64
# 174. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (72 ha) + RICE HARVEST PRICE (Rs per Quintal) (128.0 ha)
#    Estimated Income: ₹1,145,778.53
# 175. RICE HARVEST PRICE (Rs per Quintal) (132 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (68.0 ha)
#    Estimated Income: ₹1,144,364.29
# 176. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (66 ha) + RICE HARVEST PRICE (Rs per Quintal) (134.0 ha)
#    Estimated Income: ₹1,143,657.18
# 177. RICE HARVEST PRICE (Rs per Quintal) (186 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (14.0 ha)
#    Estimated Income: ₹1,143,227.94
# 178. RICE HARVEST PRICE (Rs per Quintal) (138 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (62.0 ha)
#    Estimated Income: ₹1,142,242.94
# 179. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (60 ha) + RICE HARVEST PRICE (Rs per Quintal) (140.0 ha)
#    Estimated Income: ₹1,141,535.82
# 180. RICE HARVEST PRICE (Rs per Quintal) (144 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (56.0 ha)
#    Estimated Income: ₹1,140,121.59
# 181. MAIZE HARVEST PRICE (Rs per Quintal) (12 ha) + RICE HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,139,955.71
# 182. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (54 ha) + RICE HARVEST PRICE (Rs per Quintal) (146.0 ha)
#    Estimated Income: ₹1,139,414.47
# 183. RICE HARVEST PRICE (Rs per Quintal) (150 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (50.0 ha)
#    Estimated Income: ₹1,138,000.24
# 184. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (48 ha) + RICE HARVEST PRICE (Rs per Quintal) (152.0 ha)
#    Estimated Income: ₹1,137,293.12
# 185. RICE HARVEST PRICE (Rs per Quintal) (156 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (44.0 ha)
#    Estimated Income: ₹1,135,878.89
# 186. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (42 ha) + RICE HARVEST PRICE (Rs per Quintal) (158.0 ha)
#    Estimated Income: ₹1,135,171.77
# 187. RICE HARVEST PRICE (Rs per Quintal) (162 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (38.0 ha)
#    Estimated Income: ₹1,133,757.54
# 188. RICE HARVEST PRICE (Rs per Quintal) (192 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,133,411.24
# 189. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (36 ha) + RICE HARVEST PRICE (Rs per Quintal) (164.0 ha)
#    Estimated Income: ₹1,133,050.42
# 190. RICE HARVEST PRICE (Rs per Quintal) (168 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (32.0 ha)
#    Estimated Income: ₹1,131,636.19
# 191. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (30 ha) + RICE HARVEST PRICE (Rs per Quintal) (170.0 ha)
#    Estimated Income: ₹1,130,929.07
# 192. MAIZE HARVEST PRICE (Rs per Quintal) (6 ha) + RICE HARVEST PRICE (Rs per Quintal) (194.0 ha)
#    Estimated Income: ₹1,130,139.01
# 193. RICE HARVEST PRICE (Rs per Quintal) (174 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (26.0 ha)
#    Estimated Income: ₹1,129,514.84
# 194. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (24 ha) + RICE HARVEST PRICE (Rs per Quintal) (176.0 ha)
#    Estimated Income: ₹1,128,807.72
# 195. RICE HARVEST PRICE (Rs per Quintal) (180 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (20.0 ha)
#    Estimated Income: ₹1,127,393.49
# 196. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (18 ha) + RICE HARVEST PRICE (Rs per Quintal) (182.0 ha)
#    Estimated Income: ₹1,126,686.37
# 197. RICE HARVEST PRICE (Rs per Quintal) (186 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (14.0 ha)
#    Estimated Income: ₹1,125,272.13
# 198. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (12 ha) + RICE HARVEST PRICE (Rs per Quintal) (188.0 ha)
#    Estimated Income: ₹1,124,565.02
# 199. RICE HARVEST PRICE (Rs per Quintal) (198 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (2.0 ha)
#    Estimated Income: ₹1,123,594.55
# 200. RICE HARVEST PRICE (Rs per Quintal) (192 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (8.0 ha)
#    Estimated Income: ₹1,123,150.78
# 201. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (6 ha) + RICE HARVEST PRICE (Rs per Quintal) (194.0 ha)
#    Estimated Income: ₹1,122,443.67
# 202. RICE HARVEST PRICE (Rs per Quintal) (198 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (2.0 ha)
#    Estimated Income: ₹1,121,029.43
# 203. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + RICE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,120,322.32
# 204. MAIZE HARVEST PRICE (Rs per Quintal) (0 ha) + RICE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,120,322.32
#
# Top 5 Crop Combinations for Maximum Income (Regardless of Suitability):
# 1. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,447,545.54
#    Soil Suitability: COTTON KAPAS (0.00%), MAIZE (0.00%)
# 2. RICE HARVEST PRICE (Rs per Quintal) (0 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (200.0 ha)
#    Estimated Income: ₹1,447,545.54
#    Soil Suitability: RICE (0.00%), MAIZE (0.00%)
# 3. MAIZE HARVEST PRICE (Rs per Quintal) (198 ha) + COTTON KAPAS HARVEST PRICE (Rs per Quintal) (2.0 ha)
#    Estimated Income: ₹1,444,980.43
#    Soil Suitability: MAIZE (0.00%), COTTON KAPAS (0.00%)
# 4. MAIZE HARVEST PRICE (Rs per Quintal) (198 ha) + RICE HARVEST PRICE (Rs per Quintal) (2.0 ha)
#    Estimated Income: ₹1,444,273.31
#    Soil Suitability: MAIZE (0.00%), RICE (0.00%)
# 5. COTTON KAPAS HARVEST PRICE (Rs per Quintal) (6 ha) + MAIZE HARVEST PRICE (Rs per Quintal) (194.0 ha)
#    Estimated Income: ₹1,439,850.20
#    Soil Suitability: COTTON KAPAS (0.00%), MAIZE (0.00%)
#
# No valid combinations found using the top 2 most suitable crops.
#
# Comparison for Farmer's Decision:
# ---------------------------------
# Highest Revenue Combination:
# Crops: COTTON KAPAS (0 ha) + MAIZE (200.0 ha)
# Estimated Income: ₹1,447,545.54
# Soil Suitability: COTTON KAPAS (0.00%), MAIZE (0.00%)
#
# No valid combinations using the most suitable crops were found.
# Consider improving soil conditions or exploring other crop options that may be both suitable and profitable.
# c:\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import itertools

# Load datasets
crop_df = pd.read_csv('data.csv')
yield_df = pd.read_csv('commodity_yield.csv')
icrisat_df = pd.read_csv('ICRISAT-District Level Data.csv')
price_df = pd.read_csv('pricedataset.csv')

def preprocess_data():
    """Extract crop price data from multiple sources"""
    # Get market prices
    market_prices = price_df.groupby('Commodity')['Modal Price'].mean().to_dict()
    
    # Get ICRISAT prices
    price_columns = [col for col in icrisat_df.columns if 'HARVEST PRICE' in col]
    icrisat_prices = {}
    for col in price_columns:
        crop_name = col.split(' HARVEST')[0].strip()
        icrisat_prices[crop_name] = icrisat_df[col].mean()
    
    # Merge prices with market priority
    return {**market_prices, **icrisat_prices}, price_columns

def get_suitable_crops(farm_conditions):
    """Get crops sorted by suitability using KNN"""
    X = crop_df[['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']]
    y = crop_df['label']
    
    knn = KNeighborsClassifier(n_neighbors=5)
    knn.fit(X, y)
    
    probabilities = knn.predict_proba([farm_conditions])[0]
    return sorted(zip(knn.classes_, probabilities), key=lambda x: x[1], reverse=True)

def get_crop_data(suitable_crops, yield_df, price_data):
    """Get crop details with fallback handling"""
    crop_details = {}
    for crop, prob in suitable_crops:
        crop_upper = crop.upper()
        # Get yield with fallback
        try:
            yield_val = yield_df[yield_df['Commodity'].str.lower() == crop.lower()]['Yield_Quintals_Per_Hectare'].values[0]
        except:
            yield_val = 0  # Default to 0 if no yield data
            
        # Get price with fallback
        price = price_data.get(crop_upper, 0)
        
        crop_details[crop_upper] = {
            'yield': yield_val,
            'price': price,
            'probability': prob
        }
    return crop_details

def generate_combinations(crop_data, total_area, step_size, top_crops):
    """Generate all possible combinations with step-based allocations"""
    combinations = []
    
    # Always include top crops even with 0 values
    for crop in top_crops:
        if crop not in crop_data:
            crop_data[crop] = {'yield': 0, 'price': 0, 'probability': 0}
    
    crops = list(crop_data.keys())
    
    # Create all possible pairs including top crops
    for crop1, crop2 in itertools.permutations(crops, 2):
        # Generate area splits using user-defined step size
        for area1 in range(0, int(total_area)+1, step_size):
            area2 = total_area - area1
            if area2 < 0: continue
            
            revenue = (area1 * crop_data[crop1]['yield'] * crop_data[crop1]['price']) + \
                     (area2 * crop_data[crop2]['yield'] * crop_data[crop2]['price'])
            
            combinations.append({
                'crop1': crop1,
                'area1': area1,
                'crop2': crop2,
                'area2': area2,
                'revenue': revenue,
                'crop1_prob': crop_data[crop1]['probability'],
                'crop2_prob': crop_data[crop2]['probability']
            })
    
    # Sort by descending revenue
    return sorted(combinations, key=lambda x: x['revenue'], reverse=True)

def main():
    """Main recommendation workflow"""
    # Get farm parameters
    farm_conditions = [
        float(input(f"Enter {param}: ")) for param in 
        ['N (kg/ha)', 'P (kg/ha)', 'K (kg/ha)', 'Temperature (°C)', 
         'Humidity (%)', 'pH', 'Rainfall (mm)']
    ]
    total_area = float(input("Total land area (hectares): "))
    step_size = int(input("Allocation step size (e.g., 10 for 10% increments): "))
    
    # Preprocess data
    price_data, _ = preprocess_data()
    
    # Get suitability list
    suitable_crops = get_suitable_crops(farm_conditions)
    top_crops = [crop.upper() for crop, _ in suitable_crops[:2]]  # Top 2 suitable
    
    print("\nTop Suitable Crops:")
    for i, (crop, prob) in enumerate(suitable_crops[:5], 1):
        print(f"{i}. {crop} ({prob:.1%} suitability)")
    
    # Get crop details
    crop_data = get_crop_data(suitable_crops, yield_df, price_data)
    
    # Generate combinations
    combinations = generate_combinations(crop_data, total_area, step_size, top_crops)
    
    # Display results
    print("\nTested Combinations (Top 20):")
    for combo in combinations[:20]:
        print(f"{combo['crop1']} ({combo['area1']}ha) + {combo['crop2']} ({combo['area2']}ha)")
        print(f"  Revenue: ₹{combo['revenue']:,.2f}")
        print(f"  Suitability: {combo['crop1_prob']:.1%} + {combo['crop2_prob']:.1%}")
    
    # Show optimal combination
    optimal = combinations[0]
    print("\nOptimal Revenue Combination:")
    print(f"{optimal['crop1']} ({optimal['area1']}ha) + {optimal['crop2']} ({optimal['area2']}ha)")
    print(f"Maximum Revenue: ₹{optimal['revenue']:,.2f}")
    
    # Show best suitable combination
    suitable_combos = [c for c in combinations if c['crop1'] in top_crops or c['crop2'] in top_crops]
    if suitable_combos:
        best_suitable = max(suitable_combos, key=lambda x: x['revenue'])
        print("\nBest Suitable Crop Combination:")
        print(f"{best_suitable['crop1']} ({best_suitable['area1']}ha) + {best_suitable['crop2']} ({best_suitable['area2']}ha)")
        print(f"Revenue: ₹{best_suitable['revenue']:,.2f}")
 

if __name__ == "__main__":
    main()
# Out:
# Top Suitable Crops:
# 1. coffee (60.0% suitability)
# 2. coconut (20.0% suitability)
# 3. jute (20.0% suitability)
# 4. apple (0.0% suitability)
# 5. banana (0.0% suitability)
#
# Tested Combinations (Top 20):
# COFFEE (0ha) + MAIZE (100.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 60.0% + 0.0%
# COCONUT (0ha) + MAIZE (100.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 20.0% + 0.0%
# JUTE (0ha) + MAIZE (100.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 20.0% + 0.0%
# APPLE (0ha) + MAIZE (100.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# BANANA (0ha) + MAIZE (100.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# BLACKGRAM (0ha) + MAIZE (100.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# CHICKPEA (0ha) + MAIZE (100.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# COTTON (0ha) + MAIZE (100.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# GRAPES (0ha) + MAIZE (100.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# KIDNEYBEANS (0ha) + MAIZE (100.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# LENTIL (0ha) + MAIZE (100.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# MAIZE (100ha) + COFFEE (0.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 60.0%
# MAIZE (100ha) + COCONUT (0.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 20.0%
# MAIZE (100ha) + JUTE (0.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 20.0%
# MAIZE (100ha) + APPLE (0.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# MAIZE (100ha) + BANANA (0.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# MAIZE (100ha) + BLACKGRAM (0.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# MAIZE (100ha) + CHICKPEA (0.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# MAIZE (100ha) + COTTON (0.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
# MAIZE (100ha) + GRAPES (0.0ha)
#   Revenue: ₹723,772.77
#   Suitability: 0.0% + 0.0%
#
# Optimal Revenue Combination:
# COFFEE (0ha) + MAIZE (100.0ha)
# Maximum Revenue: ₹723,772.77
#
# Best Suitable Crop Combination:
# COFFEE (0ha) + MAIZE (100.0ha)
# Revenue: ₹723,772.77
# c:\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
